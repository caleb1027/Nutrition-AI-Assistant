# %% [markdown]
# # CvT Implementation

# %%
import torch
from torch import nn, einsum
import torch.optim as optim
from torchvision import datasets
from torchvision import transforms
from einops.layers.torch import Rearrange
from einops import rearrange
from einops import repeat
from torchvision.transforms import v2

# %% [markdown]
# # Convolutional Transformer Modules

# %% [markdown]
# ## Helper Modules

# %%
device = 
(
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
device

# %%
class FeedForward(nn.Module):
    def __init__(self, dim, hidden_dim, dropout = 0.):
        super().__init__()
        self.nn = nn.Sequential(
            nn.Linear(dim, hidden_dim),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim, dim),
            nn.Dropout(dropout)
        ).to(device)
    def forward(self, x):
        return self.nn(x)

# %%
class Residual(nn.Module):
    def __init__(self, fn):
        super().__init__()
        self.fn = fn

    def forward(self, x, **kwargs):
        # allows to pass variable # of params to fn
        x = fn(x, **kwargs) + x
        return x

# %%
class Norm(nn.Module):
    def __init__(self, dim, fn):
        super().__init__()
        self.norm = nn.LayerNorm(dim).to(device)
        self.fn = fn
    def forward(self, x, **kwargs):
        # apply layer norm prior to fn
        x = self.norm(x)
        return self.fn(x, **kwargs)

# %% [markdown]
# ## CvT Specific Helper Modules

# %%
class ConvEmbedding(nn.Module):
    def __init__(self, image_size, in_channels, kernel_size, stride, size, padding, dim):
        super().__init__()
        self.conv = nn.Sequential(nn.Conv2d(in_channels, dim, kernel_size, stride, padding),
            Rearrange('b c h w -> b (h w) c', h = image_size//size, w = image_size//size),
            nn.LayerNorm(dim)).to(device)
    def forward(self, x):
        x = self.conv(x)
        return x

# %%
class ConvProj(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, padding = 0):
        super().__init__()
        self.depthwise = nn.Conv2d(in_channels, in_channels, kernel_size=kernel_size, groups=in_channels, padding=padding).to(device)
        self.bn = nn.BatchNorm2d(in_channels).to(device)
        self.pointwise = nn.Conv2d(in_channels, out_channels, kernel_size=1).to(device)
    def forward(self, input):
        x = self.depthwise(input)
        x = self.bn(x)
        x = self.pointwise(x)
        return x

# %%
class ConvAttention(nn.Module):
     def __init__(self, dim, img_size, heads = 8, dim_head = 64, kernel_size=3, q_stride=1, k_stride=1, v_stride=1, dropout = 0.,
                 last_stage=False):

        super().__init__()
        self.last_stage = last_stage
        self.img_size = img_size
        inner_dim = dim_head *  heads
        project_out = not (heads == 1 and dim_head == dim)

        # map to q,k,v
        self.heads = heads
        self.scale = dim_head ** -0.5
        pad = (kernel_size - q_stride)//2
        self.to_q = ConvProj(dim, inner_dim, kernel_size, pad).to(device)
        self.to_k = ConvProj(dim, inner_dim, kernel_size, pad).to(device)
        self.to_v = ConvProj(dim, inner_dim, kernel_size, pad).to(device)

        # use if outputting, else use identity
        self.out = nn.Sequential(nn.Linear(inner_dim, dim), nn.Dropout(dropout)).to(device) if project_out else nn.Identity().to(device)

     def forward(self, x):
        b, n, _, h = *x.shape, self.heads
        if self.last_stage:
            cls_token = x[:, 0]
            x = x[:, 1:]
            cls_token = rearrange(cls_token.unsqueeze(1), 'b n (h d) -> b h n d', h = h)
        x = rearrange(x, 'b (l w) n -> b n l w', l=self.img_size, w=self.img_size)
        q = self.to_q(x)
        q = rearrange(q, 'b (h d) l w -> b h (l w) d', h=h)

        v = self.to_v(x)
        v = rearrange(v, 'b (h d) l w -> b h (l w) d', h=h)

        k = self.to_k(x)
        k = rearrange(k, 'b (h d) l w -> b h (l w) d', h=h)

        if self.last_stage:
            q = torch.cat((cls_token, q), dim=2)
            v = torch.cat((cls_token, v), dim=2)
            k = torch.cat((cls_token, k), dim=2)


        dots = einsum('b h i d, b h j d -> b h i j', q, k) * self.scale

        attn = dots.softmax(dim=-1)

        out = einsum('b h i j, b h j d -> b h i d', attn, v)
        out = rearrange(out, 'b h n d -> b n (h d)')
        out =  self.out(out)
        return out

# %%
class Transformer(nn.Module):
    def __init__(self, dim, img_size, depth, heads, dim_heads, mlp_dim, dropout=0., last_stage=False):
        super().__init__()
        self.modules = []
        for _ in range(depth):
            self.modules.append(nn.ModuleList([
                Norm(dim, ConvAttention(dim, img_size, heads=heads, dim_head=dim_heads, dropout=dropout, last_stage=last_stage)).to(device),
                Norm(dim, FeedForward(dim, mlp_dim, dropout=dropout)).to(device)
            ]))
    def forward(self, x):
        for attn, ff in self.modules:
            x = attn(x) + x
            x = ff(x) + x
        return x

# %% [markdown]
# ## CvT Class

# %%
class CvT(nn.Module):
    def __init__(self, image_size, in_channels, num_classes, dim=64):
        super().__init__()

        self.dim = dim
        # Stage 1: Conv, Transformer
        trans = Transformer(dim, image_size//4, 1, 1, dim_heads=self.dim, mlp_dim=dim*4).to(device)
        self.stage_1_embed = ConvEmbedding(image_size, in_channels, 7, 4, 4, 2, self.dim).to(device)
        self.stage_1_transformer = nn.Sequential(trans,
                                                  Rearrange('b (h w) c -> b c h w', h = image_size//4, w = image_size//4)).to(device)
        # Stage 2: Conv, Transformer
        in_channels = dim
        scale = 3//1
        dim = dim * scale
        self.stage_2_embed = ConvEmbedding(image_size, in_channels, 3, 2, 8, 1, dim).to(device)
        trans = Transformer(dim, image_size//8, 2, 3, dim_heads=self.dim, mlp_dim=dim*4).to(device)
        self.stage_2_transformer = nn.Sequential(trans,
                                                  Rearrange('b (h w) c -> b c h w', h = image_size//8, w = image_size//8)).to(device)
        # Stage 3: Conv, Transformer, FFN
        in_channels = dim
        scale = 6//3
        dim = scale * dim
        self.stage_3_embed = ConvEmbedding(image_size, in_channels, 3, 2, 16, 1, dim).to(device)
        self.stage_3_transformer = nn.Sequential(Transformer(dim, image_size//16, 10, 6, dim_heads=self.dim, mlp_dim=dim*4, last_stage=True)).to(device)
        self.cls_token = nn.Parameter(torch.randn(1, 1, dim)).to(device)

        self.mlp = nn.Sequential(
            nn.LayerNorm(dim),
            nn.Linear(dim, num_classes)
        ).to(device)


    def forward(self, img):

        xs = self.stage_1_embed(img)
        xs = self.stage_1_transformer(xs)

        xs = self.stage_2_embed(xs)
        xs = self.stage_2_transformer(xs)

        xs = self.stage_3_embed(xs)
        b, n, _ = xs.shape
        cls_tokens = repeat(self.cls_token, '() n d -> b n d', b=b)
        xs = torch.cat((cls_tokens, xs), dim=1)
        xs = self.stage_3_transformer(xs)
        xs = xs[:, 0]

        xs = self.mlp(xs)
        return xs

# %% [markdown]
# # Model Training

# %% [markdown]
# ## Load and Transform Data

# %%
transform = v2.Compose([v2.ToImage(), v2.ToDtype(torch.float32, scale=True), v2.Resize((224, 224))])

# %%
food101_train_data = datasets.Food101('/', split="train", download=True, transform=transform)
food101_test_data = datasets.Food101('/', split="test", transform=transform)

train_loader = torch.utils.data.DataLoader(food101_train_data,
                                          batch_size=32,
                                          shuffle=True)

food101_train_data.__getitem__(2)[0].shape
# Out:
# torch.Size([3, 224, 224])

# %%
cvt = CvT(224, 3, 101)
cvt.eval()
# Out:
# CvT(
#   (stage_1_embed): ConvEmbedding(
#     (conv): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(4, 4), padding=(2, 2))
#       (1): Rearrange('b c h w -> b (h w) c', h=56, w=56)
#       (2): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (stage_1_transformer): Sequential(
#     (0): Transformer()
#     (1): Rearrange('b (h w) c -> b c h w', h=56, w=56)
#   )
#   (stage_2_embed): ConvEmbedding(
#     (conv): Sequential(
#       (0): Conv2d(64, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): Rearrange('b c h w -> b (h w) c', h=28, w=28)
#       (2): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (stage_2_transformer): Sequential(
#     (0): Transformer()
#     (1): Rearrange('b (h w) c -> b c h w', h=28, w=28)
#   )
#   (stage_3_embed): ConvEmbedding(
#     (conv): Sequential(
#       (0): Conv2d(192, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (1): Rearrange('b c h w -> b (h w) c', h=14, w=14)
#       (2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (stage_3_transformer): Sequential(
#     (0): Transformer()
#   )
#   (mlp): Sequential(
#     (0): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=384, out_features=101, bias=True)
#   )
# )

# %%
def train_loop(loss_fn, optim, trainloader, net):
    running_loss = 0
    for i, data in enumerate(trainloader, 0):
        
        inputs, labels = data
        inputs = inputs
        labels = labels
        # zero parameter gradients
        optim.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = loss_fn(outputs, labels)
        loss.backward()
        optim.step()

        # print statistics
        running_loss += loss.item()
        if i % 100 == 99:    # print every 100 mini-batches
            print(f'loss: {running_loss / 100:.3f}')
            running_loss = 0.0
        print(loss)

def train(epochs, trainloader, net, loss_fn=nn.CrossEntropyLoss(), optimizer=optim.Adam(cvt.parameters(),lr=0.001)):
    net.train()
    for i in range(epochs):
        train_loop(loss_fn, optimizer, trainloader, net)
    print("Done")

# %%
optimizer = torch.optim.Adam(cvt.parameters(), lr=1e-3)
train(1, train_loader, cvt, optimizer=optimizer)

# Save model
PATH = "cvt_impl.pt"
torch.save(cvt.state_dict(), PATH)
# Out:
# tensor(4.5432, grad_fn=<NllLossBackward0>)
# tensor(4.6857, grad_fn=<NllLossBackward0>)
# tensor(4.6629, grad_fn=<NllLossBackward0>)
# tensor(4.6905, grad_fn=<NllLossBackward0>)
# tensor(4.8349, grad_fn=<NllLossBackward0>)
# tensor(4.5938, grad_fn=<NllLossBackward0>)
# tensor(4.5737, grad_fn=<NllLossBackward0>)
# tensor(4.8321, grad_fn=<NllLossBackward0>)
# tensor(4.7636, grad_fn=<NllLossBackward0>)
# tensor(5.1685, grad_fn=<NllLossBackward0>)
# tensor(4.8618, grad_fn=<NllLossBackward0>)
# tensor(4.7726, grad_fn=<NllLossBackward0>)
# tensor(4.5561, grad_fn=<NllLossBackward0>)
# tensor(4.6430, grad_fn=<NllLossBackward0>)
# tensor(4.6156, grad_fn=<NllLossBackward0>)
# tensor(4.6963, grad_fn=<NllLossBackward0>)
# tensor(4.8112, grad_fn=<NllLossBackward0>)
# tensor(4.6130, grad_fn=<NllLossBackward0>)
# tensor(4.6943, grad_fn=<NllLossBackward0>)
# tensor(4.5599, grad_fn=<NllLossBackward0>)
# tensor(4.5730, grad_fn=<NllLossBackward0>)
# tensor(4.8356, grad_fn=<NllLossBackward0>)
# tensor(4.5910, grad_fn=<NllLossBackward0>)
# tensor(4.5900, grad_fn=<NllLossBackward0>)
# tensor(4.6959, grad_fn=<NllLossBackward0>)
# tensor(4.5628, grad_fn=<NllLossBackward0>)
# tensor(4.6968, grad_fn=<NllLossBackward0>)
# tensor(4.5574, grad_fn=<NllLossBackward0>)
# tensor(4.8091, grad_fn=<NllLossBackward0>)
# tensor(4.6354, grad_fn=<NllLossBackward0>)
# tensor(4.8790, grad_fn=<NllLossBackward0>)
# tensor(4.7068, grad_fn=<NllLossBackward0>)
# tensor(4.6956, grad_fn=<NllLossBackward0>)
# tensor(4.6913, grad_fn=<NllLossBackward0>)
# tensor(4.6167, grad_fn=<NllLossBackward0>)
# tensor(4.6962, grad_fn=<NllLossBackward0>)
# tensor(4.6549, grad_fn=<NllLossBackward0>)
# tensor(4.7128, grad_fn=<NllLossBackward0>)
# tensor(4.5276, grad_fn=<NllLossBackward0>)
# tensor(4.6571, grad_fn=<NllLossBackward0>)
# tensor(4.5009, grad_fn=<NllLossBackward0>)
# tensor(4.7203, grad_fn=<NllLossBackward0>)
# tensor(4.7555, grad_fn=<NllLossBackward0>)
# tensor(4.6860, grad_fn=<NllLossBackward0>)
# tensor(4.6347, grad_fn=<NllLossBackward0>)
# tensor(4.5325, grad_fn=<NllLossBackward0>)
# tensor(4.6340, grad_fn=<NllLossBackward0>)
# tensor(4.7319, grad_fn=<NllLossBackward0>)
# tensor(4.4631, grad_fn=<NllLossBackward0>)
# tensor(4.7323, grad_fn=<NllLossBackward0>)
# tensor(4.5466, grad_fn=<NllLossBackward0>)
# tensor(4.6515, grad_fn=<NllLossBackward0>)
# tensor(4.5812, grad_fn=<NllLossBackward0>)
# tensor(4.4448, grad_fn=<NllLossBackward0>)
# tensor(4.7765, grad_fn=<NllLossBackward0>)
# tensor(4.6196, grad_fn=<NllLossBackward0>)
# tensor(4.6269, grad_fn=<NllLossBackward0>)
# tensor(4.7415, grad_fn=<NllLossBackward0>)
# tensor(4.4837, grad_fn=<NllLossBackward0>)
# tensor(4.4849, grad_fn=<NllLossBackward0>)
# tensor(4.7490, grad_fn=<NllLossBackward0>)
# tensor(4.6688, grad_fn=<NllLossBackward0>)
# tensor(4.5227, grad_fn=<NllLossBackward0>)
# tensor(4.5542, grad_fn=<NllLossBackward0>)
# tensor(4.6006, grad_fn=<NllLossBackward0>)
# tensor(4.7310, grad_fn=<NllLossBackward0>)
# tensor(4.6196, grad_fn=<NllLossBackward0>)
# tensor(4.3010, grad_fn=<NllLossBackward0>)
# tensor(4.4442, grad_fn=<NllLossBackward0>)
# tensor(4.4461, grad_fn=<NllLossBackward0>)
# tensor(4.7444, grad_fn=<NllLossBackward0>)
# tensor(4.5842, grad_fn=<NllLossBackward0>)
# tensor(4.5876, grad_fn=<NllLossBackward0>)
# tensor(4.8058, grad_fn=<NllLossBackward0>)
# tensor(4.3438, grad_fn=<NllLossBackward0>)
# tensor(4.3930, grad_fn=<NllLossBackward0>)
# tensor(4.6251, grad_fn=<NllLossBackward0>)
# tensor(4.5675, grad_fn=<NllLossBackward0>)
# tensor(4.6835, grad_fn=<NllLossBackward0>)
# tensor(4.4718, grad_fn=<NllLossBackward0>)
# tensor(4.6852, grad_fn=<NllLossBackward0>)
# tensor(4.4996, grad_fn=<NllLossBackward0>)
# tensor(4.7027, grad_fn=<NllLossBackward0>)
# tensor(4.6117, grad_fn=<NllLossBackward0>)
# tensor(4.7594, grad_fn=<NllLossBackward0>)
# tensor(4.4023, grad_fn=<NllLossBackward0>)
# tensor(4.7006, grad_fn=<NllLossBackward0>)
# tensor(4.5690, grad_fn=<NllLossBackward0>)
# tensor(4.6361, grad_fn=<NllLossBackward0>)
# tensor(4.6561, grad_fn=<NllLossBackward0>)
# tensor(4.8099, grad_fn=<NllLossBackward0>)
# tensor(4.8318, grad_fn=<NllLossBackward0>)
# tensor(4.4858, grad_fn=<NllLossBackward0>)
# tensor(4.7027, grad_fn=<NllLossBackward0>)
# tensor(4.5080, grad_fn=<NllLossBackward0>)
# tensor(4.6785, grad_fn=<NllLossBackward0>)
# tensor(4.5198, grad_fn=<NllLossBackward0>)
# tensor(4.5265, grad_fn=<NllLossBackward0>)
# tensor(4.6726, grad_fn=<NllLossBackward0>)
# loss: 4.639
# tensor(4.5910, grad_fn=<NllLossBackward0>)
# tensor(4.5572, grad_fn=<NllLossBackward0>)
# tensor(4.6001, grad_fn=<NllLossBackward0>)
# tensor(4.4410, grad_fn=<NllLossBackward0>)
# tensor(4.6516, grad_fn=<NllLossBackward0>)
# tensor(4.7486, grad_fn=<NllLossBackward0>)
# tensor(4.4641, grad_fn=<NllLossBackward0>)
# tensor(4.6771, grad_fn=<NllLossBackward0>)
# tensor(4.5952, grad_fn=<NllLossBackward0>)
# tensor(4.4608, grad_fn=<NllLossBackward0>)
# tensor(4.6767, grad_fn=<NllLossBackward0>)
# tensor(4.5644, grad_fn=<NllLossBackward0>)
# tensor(4.7075, grad_fn=<NllLossBackward0>)
# tensor(4.5705, grad_fn=<NllLossBackward0>)
# tensor(4.5479, grad_fn=<NllLossBackward0>)
# tensor(4.4324, grad_fn=<NllLossBackward0>)
# tensor(4.5592, grad_fn=<NllLossBackward0>)
# tensor(4.8118, grad_fn=<NllLossBackward0>)
# tensor(4.4275, grad_fn=<NllLossBackward0>)
# tensor(4.6056, grad_fn=<NllLossBackward0>)
# tensor(4.4239, grad_fn=<NllLossBackward0>)
# tensor(4.5724, grad_fn=<NllLossBackward0>)
# tensor(4.5888, grad_fn=<NllLossBackward0>)
# tensor(4.4385, grad_fn=<NllLossBackward0>)
# tensor(4.8505, grad_fn=<NllLossBackward0>)
# tensor(4.6817, grad_fn=<NllLossBackward0>)
# tensor(4.7066, grad_fn=<NllLossBackward0>)
# tensor(4.6169, grad_fn=<NllLossBackward0>)
# tensor(4.7434, grad_fn=<NllLossBackward0>)
# tensor(4.5582, grad_fn=<NllLossBackward0>)
# tensor(4.2778, grad_fn=<NllLossBackward0>)
# tensor(4.5015, grad_fn=<NllLossBackward0>)
# tensor(4.5047, grad_fn=<NllLossBackward0>)
# tensor(4.3989, grad_fn=<NllLossBackward0>)
# tensor(4.5830, grad_fn=<NllLossBackward0>)
# tensor(4.6077, grad_fn=<NllLossBackward0>)
# tensor(4.3895, grad_fn=<NllLossBackward0>)
# tensor(4.6698, grad_fn=<NllLossBackward0>)
# tensor(4.7703, grad_fn=<NllLossBackward0>)
# tensor(4.3513, grad_fn=<NllLossBackward0>)
# tensor(4.5170, grad_fn=<NllLossBackward0>)
# tensor(4.3060, grad_fn=<NllLossBackward0>)
# tensor(4.7811, grad_fn=<NllLossBackward0>)
# tensor(4.5023, grad_fn=<NllLossBackward0>)
# tensor(4.5409, grad_fn=<NllLossBackward0>)
# tensor(4.5229, grad_fn=<NllLossBackward0>)
# tensor(4.3933, grad_fn=<NllLossBackward0>)
# tensor(4.2626, grad_fn=<NllLossBackward0>)
# tensor(4.5050, grad_fn=<NllLossBackward0>)
# tensor(4.1931, grad_fn=<NllLossBackward0>)
# tensor(4.6753, grad_fn=<NllLossBackward0>)
# tensor(4.4334, grad_fn=<NllLossBackward0>)
# tensor(4.4508, grad_fn=<NllLossBackward0>)
# tensor(4.7373, grad_fn=<NllLossBackward0>)
# tensor(4.5542, grad_fn=<NllLossBackward0>)
# tensor(4.5494, grad_fn=<NllLossBackward0>)
# tensor(4.5914, grad_fn=<NllLossBackward0>)
# tensor(4.8713, grad_fn=<NllLossBackward0>)
# tensor(4.6989, grad_fn=<NllLossBackward0>)
# tensor(4.6182, grad_fn=<NllLossBackward0>)
# tensor(4.5034, grad_fn=<NllLossBackward0>)
# tensor(4.7583, grad_fn=<NllLossBackward0>)
# tensor(4.3679, grad_fn=<NllLossBackward0>)
# tensor(4.4024, grad_fn=<NllLossBackward0>)
# tensor(4.5744, grad_fn=<NllLossBackward0>)
# tensor(4.7276, grad_fn=<NllLossBackward0>)
# tensor(4.5175, grad_fn=<NllLossBackward0>)
# tensor(4.5309, grad_fn=<NllLossBackward0>)
# tensor(4.6183, grad_fn=<NllLossBackward0>)
# tensor(4.6437, grad_fn=<NllLossBackward0>)
# tensor(4.5174, grad_fn=<NllLossBackward0>)
# tensor(4.5217, grad_fn=<NllLossBackward0>)
# tensor(4.6229, grad_fn=<NllLossBackward0>)
# tensor(4.5192, grad_fn=<NllLossBackward0>)
# tensor(4.5156, grad_fn=<NllLossBackward0>)
# tensor(4.6894, grad_fn=<NllLossBackward0>)
# tensor(4.4919, grad_fn=<NllLossBackward0>)
# tensor(4.7172, grad_fn=<NllLossBackward0>)
# tensor(4.3124, grad_fn=<NllLossBackward0>)
# tensor(4.6258, grad_fn=<NllLossBackward0>)
# tensor(4.5136, grad_fn=<NllLossBackward0>)
# tensor(4.3955, grad_fn=<NllLossBackward0>)
# tensor(4.3969, grad_fn=<NllLossBackward0>)
# tensor(4.3358, grad_fn=<NllLossBackward0>)
# tensor(4.6313, grad_fn=<NllLossBackward0>)
# tensor(4.6117, grad_fn=<NllLossBackward0>)
# tensor(4.4208, grad_fn=<NllLossBackward0>)
# tensor(4.4891, grad_fn=<NllLossBackward0>)
# tensor(4.5598, grad_fn=<NllLossBackward0>)
# tensor(4.4584, grad_fn=<NllLossBackward0>)
# tensor(4.5612, grad_fn=<NllLossBackward0>)
# tensor(4.6319, grad_fn=<NllLossBackward0>)
# tensor(4.5186, grad_fn=<NllLossBackward0>)
# tensor(4.5379, grad_fn=<NllLossBackward0>)
# tensor(4.3787, grad_fn=<NllLossBackward0>)
# tensor(4.6228, grad_fn=<NllLossBackward0>)
# tensor(4.5894, grad_fn=<NllLossBackward0>)
# tensor(4.3423, grad_fn=<NllLossBackward0>)
# tensor(4.3907, grad_fn=<NllLossBackward0>)
# tensor(4.4924, grad_fn=<NllLossBackward0>)
# loss: 4.546
# tensor(4.4934, grad_fn=<NllLossBackward0>)
# tensor(4.4341, grad_fn=<NllLossBackward0>)
# tensor(4.5568, grad_fn=<NllLossBackward0>)
# tensor(4.4015, grad_fn=<NllLossBackward0>)
# tensor(4.5179, grad_fn=<NllLossBackward0>)
# tensor(4.4595, grad_fn=<NllLossBackward0>)
# tensor(4.5050, grad_fn=<NllLossBackward0>)
# tensor(4.6714, grad_fn=<NllLossBackward0>)
# tensor(4.8511, grad_fn=<NllLossBackward0>)
# tensor(4.5577, grad_fn=<NllLossBackward0>)
# tensor(4.3677, grad_fn=<NllLossBackward0>)
# tensor(4.3714, grad_fn=<NllLossBackward0>)
# tensor(4.5851, grad_fn=<NllLossBackward0>)
# tensor(4.6255, grad_fn=<NllLossBackward0>)
# tensor(4.5488, grad_fn=<NllLossBackward0>)
# tensor(4.7215, grad_fn=<NllLossBackward0>)
# tensor(4.6810, grad_fn=<NllLossBackward0>)
# tensor(4.3690, grad_fn=<NllLossBackward0>)
# tensor(4.3793, grad_fn=<NllLossBackward0>)
# tensor(4.8802, grad_fn=<NllLossBackward0>)
# tensor(4.6588, grad_fn=<NllLossBackward0>)
# tensor(4.6775, grad_fn=<NllLossBackward0>)
# tensor(4.3646, grad_fn=<NllLossBackward0>)
# tensor(4.6687, grad_fn=<NllLossBackward0>)
# tensor(4.6581, grad_fn=<NllLossBackward0>)
# tensor(4.3790, grad_fn=<NllLossBackward0>)
# tensor(4.5784, grad_fn=<NllLossBackward0>)
# tensor(4.5769, grad_fn=<NllLossBackward0>)
# tensor(4.2461, grad_fn=<NllLossBackward0>)
# tensor(4.5004, grad_fn=<NllLossBackward0>)
# tensor(4.5007, grad_fn=<NllLossBackward0>)
# tensor(4.5766, grad_fn=<NllLossBackward0>)
# tensor(4.4860, grad_fn=<NllLossBackward0>)
# tensor(4.4643, grad_fn=<NllLossBackward0>)
# tensor(4.6050, grad_fn=<NllLossBackward0>)
# tensor(4.5126, grad_fn=<NllLossBackward0>)
# tensor(4.2433, grad_fn=<NllLossBackward0>)
# tensor(4.5421, grad_fn=<NllLossBackward0>)
# tensor(4.6188, grad_fn=<NllLossBackward0>)
# tensor(4.7591, grad_fn=<NllLossBackward0>)
# tensor(4.4513, grad_fn=<NllLossBackward0>)
# tensor(4.5785, grad_fn=<NllLossBackward0>)
# tensor(4.3495, grad_fn=<NllLossBackward0>)
# tensor(4.4611, grad_fn=<NllLossBackward0>)
# tensor(4.5958, grad_fn=<NllLossBackward0>)
# tensor(4.3955, grad_fn=<NllLossBackward0>)
# tensor(4.4803, grad_fn=<NllLossBackward0>)
# tensor(4.5315, grad_fn=<NllLossBackward0>)
# tensor(4.3109, grad_fn=<NllLossBackward0>)
# tensor(4.3507, grad_fn=<NllLossBackward0>)
# tensor(4.4622, grad_fn=<NllLossBackward0>)
# tensor(4.2683, grad_fn=<NllLossBackward0>)
# tensor(4.4186, grad_fn=<NllLossBackward0>)
# tensor(4.5625, grad_fn=<NllLossBackward0>)
# tensor(4.3209, grad_fn=<NllLossBackward0>)
# tensor(4.3480, grad_fn=<NllLossBackward0>)
# tensor(4.3109, grad_fn=<NllLossBackward0>)
# tensor(4.1595, grad_fn=<NllLossBackward0>)
# tensor(4.4307, grad_fn=<NllLossBackward0>)
# tensor(4.5775, grad_fn=<NllLossBackward0>)
# tensor(4.5003, grad_fn=<NllLossBackward0>)
# tensor(4.4439, grad_fn=<NllLossBackward0>)
# tensor(4.4962, grad_fn=<NllLossBackward0>)
# tensor(4.6384, grad_fn=<NllLossBackward0>)
# tensor(4.4620, grad_fn=<NllLossBackward0>)
# tensor(4.6115, grad_fn=<NllLossBackward0>)
# tensor(4.5110, grad_fn=<NllLossBackward0>)
# tensor(4.8452, grad_fn=<NllLossBackward0>)
# tensor(4.2521, grad_fn=<NllLossBackward0>)
# tensor(4.3348, grad_fn=<NllLossBackward0>)
# tensor(4.6065, grad_fn=<NllLossBackward0>)
# tensor(4.6538, grad_fn=<NllLossBackward0>)
# tensor(4.4524, grad_fn=<NllLossBackward0>)
# tensor(4.6688, grad_fn=<NllLossBackward0>)
# tensor(4.5035, grad_fn=<NllLossBackward0>)
# tensor(4.5940, grad_fn=<NllLossBackward0>)
# tensor(4.4366, grad_fn=<NllLossBackward0>)
# tensor(4.4170, grad_fn=<NllLossBackward0>)
# tensor(4.5570, grad_fn=<NllLossBackward0>)
# tensor(4.4049, grad_fn=<NllLossBackward0>)
# tensor(4.4288, grad_fn=<NllLossBackward0>)
# tensor(4.5421, grad_fn=<NllLossBackward0>)
# tensor(4.7109, grad_fn=<NllLossBackward0>)
# tensor(4.4741, grad_fn=<NllLossBackward0>)
# tensor(4.5312, grad_fn=<NllLossBackward0>)
# tensor(4.8878, grad_fn=<NllLossBackward0>)
# tensor(4.3270, grad_fn=<NllLossBackward0>)
# tensor(4.3884, grad_fn=<NllLossBackward0>)
# tensor(4.6214, grad_fn=<NllLossBackward0>)
# tensor(4.6455, grad_fn=<NllLossBackward0>)
# tensor(4.3226, grad_fn=<NllLossBackward0>)
# tensor(4.3905, grad_fn=<NllLossBackward0>)
# tensor(4.3126, grad_fn=<NllLossBackward0>)
# tensor(4.4817, grad_fn=<NllLossBackward0>)
# tensor(4.4881, grad_fn=<NllLossBackward0>)
# tensor(4.5359, grad_fn=<NllLossBackward0>)
# tensor(4.5851, grad_fn=<NllLossBackward0>)
# tensor(4.4435, grad_fn=<NllLossBackward0>)
# tensor(4.4461, grad_fn=<NllLossBackward0>)
# tensor(4.5404, grad_fn=<NllLossBackward0>)
# loss: 4.502
# tensor(4.2830, grad_fn=<NllLossBackward0>)
# tensor(4.6495, grad_fn=<NllLossBackward0>)
# tensor(4.6198, grad_fn=<NllLossBackward0>)
# tensor(4.5403, grad_fn=<NllLossBackward0>)
# tensor(4.6041, grad_fn=<NllLossBackward0>)
# tensor(4.6868, grad_fn=<NllLossBackward0>)
# tensor(4.5070, grad_fn=<NllLossBackward0>)
# tensor(4.4670, grad_fn=<NllLossBackward0>)
# tensor(4.5300, grad_fn=<NllLossBackward0>)
# tensor(4.5610, grad_fn=<NllLossBackward0>)
# tensor(4.5914, grad_fn=<NllLossBackward0>)
# tensor(4.5525, grad_fn=<NllLossBackward0>)
# tensor(4.2331, grad_fn=<NllLossBackward0>)
# tensor(4.4143, grad_fn=<NllLossBackward0>)
# tensor(4.3281, grad_fn=<NllLossBackward0>)
# tensor(4.6145, grad_fn=<NllLossBackward0>)
# tensor(4.4799, grad_fn=<NllLossBackward0>)
# tensor(4.4069, grad_fn=<NllLossBackward0>)
# tensor(4.6228, grad_fn=<NllLossBackward0>)
# tensor(4.4996, grad_fn=<NllLossBackward0>)
# tensor(4.6415, grad_fn=<NllLossBackward0>)
# tensor(4.5997, grad_fn=<NllLossBackward0>)
# tensor(4.4879, grad_fn=<NllLossBackward0>)
# tensor(4.4499, grad_fn=<NllLossBackward0>)
# tensor(4.2596, grad_fn=<NllLossBackward0>)
# tensor(4.3374, grad_fn=<NllLossBackward0>)
# tensor(4.2531, grad_fn=<NllLossBackward0>)
# tensor(4.7913, grad_fn=<NllLossBackward0>)
# tensor(4.3127, grad_fn=<NllLossBackward0>)
# tensor(4.3389, grad_fn=<NllLossBackward0>)
# tensor(4.3093, grad_fn=<NllLossBackward0>)
# tensor(4.4038, grad_fn=<NllLossBackward0>)
# tensor(4.3865, grad_fn=<NllLossBackward0>)
# tensor(4.5078, grad_fn=<NllLossBackward0>)
# tensor(4.5224, grad_fn=<NllLossBackward0>)
# tensor(4.2300, grad_fn=<NllLossBackward0>)
# tensor(4.6886, grad_fn=<NllLossBackward0>)
# tensor(4.4888, grad_fn=<NllLossBackward0>)
# tensor(4.4736, grad_fn=<NllLossBackward0>)
# tensor(4.2162, grad_fn=<NllLossBackward0>)
# tensor(4.3950, grad_fn=<NllLossBackward0>)
# tensor(4.4261, grad_fn=<NllLossBackward0>)
# tensor(4.5446, grad_fn=<NllLossBackward0>)
# tensor(4.4853, grad_fn=<NllLossBackward0>)
# tensor(4.2393, grad_fn=<NllLossBackward0>)
# tensor(4.2554, grad_fn=<NllLossBackward0>)
# tensor(4.4648, grad_fn=<NllLossBackward0>)
# tensor(4.5682, grad_fn=<NllLossBackward0>)
# tensor(4.6167, grad_fn=<NllLossBackward0>)
# tensor(4.4450, grad_fn=<NllLossBackward0>)
# tensor(4.3720, grad_fn=<NllLossBackward0>)
# tensor(4.4765, grad_fn=<NllLossBackward0>)
# tensor(4.4994, grad_fn=<NllLossBackward0>)
# tensor(4.5138, grad_fn=<NllLossBackward0>)
# tensor(4.7978, grad_fn=<NllLossBackward0>)
# tensor(4.5306, grad_fn=<NllLossBackward0>)
# tensor(4.1625, grad_fn=<NllLossBackward0>)
# tensor(4.6264, grad_fn=<NllLossBackward0>)
# tensor(4.3836, grad_fn=<NllLossBackward0>)
# tensor(4.4748, grad_fn=<NllLossBackward0>)
# tensor(4.4476, grad_fn=<NllLossBackward0>)
# tensor(4.4749, grad_fn=<NllLossBackward0>)
# tensor(4.5292, grad_fn=<NllLossBackward0>)
# tensor(4.6940, grad_fn=<NllLossBackward0>)
# tensor(4.7213, grad_fn=<NllLossBackward0>)
# tensor(4.2719, grad_fn=<NllLossBackward0>)
# tensor(4.3051, grad_fn=<NllLossBackward0>)
# tensor(4.3492, grad_fn=<NllLossBackward0>)
# tensor(4.3945, grad_fn=<NllLossBackward0>)
# tensor(4.3025, grad_fn=<NllLossBackward0>)
# tensor(4.7189, grad_fn=<NllLossBackward0>)
# tensor(4.5469, grad_fn=<NllLossBackward0>)
# tensor(4.2989, grad_fn=<NllLossBackward0>)
# tensor(4.6274, grad_fn=<NllLossBackward0>)
# tensor(4.2278, grad_fn=<NllLossBackward0>)
# tensor(4.4360, grad_fn=<NllLossBackward0>)
# tensor(4.4062, grad_fn=<NllLossBackward0>)
# tensor(4.3781, grad_fn=<NllLossBackward0>)
# tensor(4.5930, grad_fn=<NllLossBackward0>)
# tensor(4.4888, grad_fn=<NllLossBackward0>)
# tensor(4.4044, grad_fn=<NllLossBackward0>)
# tensor(4.5086, grad_fn=<NllLossBackward0>)
# tensor(4.4511, grad_fn=<NllLossBackward0>)
# tensor(4.4372, grad_fn=<NllLossBackward0>)
# tensor(4.4343, grad_fn=<NllLossBackward0>)
# tensor(4.6411, grad_fn=<NllLossBackward0>)
# tensor(4.4239, grad_fn=<NllLossBackward0>)
# tensor(4.3601, grad_fn=<NllLossBackward0>)
# tensor(4.3652, grad_fn=<NllLossBackward0>)
# tensor(4.5297, grad_fn=<NllLossBackward0>)
# tensor(4.6191, grad_fn=<NllLossBackward0>)
# tensor(4.6491, grad_fn=<NllLossBackward0>)
# tensor(4.4362, grad_fn=<NllLossBackward0>)
# tensor(4.5194, grad_fn=<NllLossBackward0>)
# tensor(4.2400, grad_fn=<NllLossBackward0>)
# tensor(4.3133, grad_fn=<NllLossBackward0>)
# tensor(4.2879, grad_fn=<NllLossBackward0>)
# tensor(4.0790, grad_fn=<NllLossBackward0>)
# tensor(4.5573, grad_fn=<NllLossBackward0>)
# tensor(4.4467, grad_fn=<NllLossBackward0>)
# loss: 4.462
# tensor(4.4415, grad_fn=<NllLossBackward0>)
# tensor(4.5206, grad_fn=<NllLossBackward0>)
# tensor(4.6005, grad_fn=<NllLossBackward0>)
# tensor(4.3779, grad_fn=<NllLossBackward0>)
# tensor(4.3906, grad_fn=<NllLossBackward0>)
# tensor(4.4682, grad_fn=<NllLossBackward0>)
# tensor(4.5724, grad_fn=<NllLossBackward0>)
# tensor(4.3342, grad_fn=<NllLossBackward0>)
# tensor(4.4224, grad_fn=<NllLossBackward0>)
# tensor(4.3980, grad_fn=<NllLossBackward0>)
# tensor(4.4715, grad_fn=<NllLossBackward0>)
# tensor(4.1907, grad_fn=<NllLossBackward0>)
# tensor(4.3477, grad_fn=<NllLossBackward0>)
# tensor(4.5848, grad_fn=<NllLossBackward0>)
# tensor(4.6589, grad_fn=<NllLossBackward0>)
# tensor(4.7091, grad_fn=<NllLossBackward0>)
# tensor(4.2652, grad_fn=<NllLossBackward0>)
# tensor(4.4435, grad_fn=<NllLossBackward0>)
# tensor(4.4944, grad_fn=<NllLossBackward0>)
# tensor(4.4541, grad_fn=<NllLossBackward0>)
# tensor(4.5986, grad_fn=<NllLossBackward0>)
# tensor(4.5108, grad_fn=<NllLossBackward0>)
# tensor(4.3072, grad_fn=<NllLossBackward0>)
# tensor(4.6229, grad_fn=<NllLossBackward0>)
# tensor(4.3213, grad_fn=<NllLossBackward0>)
# tensor(4.1556, grad_fn=<NllLossBackward0>)
# tensor(4.2659, grad_fn=<NllLossBackward0>)
# tensor(4.0110, grad_fn=<NllLossBackward0>)
# tensor(4.1519, grad_fn=<NllLossBackward0>)
# tensor(4.3147, grad_fn=<NllLossBackward0>)
# tensor(4.4395, grad_fn=<NllLossBackward0>)
# tensor(4.4858, grad_fn=<NllLossBackward0>)
# tensor(4.4521, grad_fn=<NllLossBackward0>)
# tensor(4.4160, grad_fn=<NllLossBackward0>)
# tensor(4.4506, grad_fn=<NllLossBackward0>)
# tensor(4.5284, grad_fn=<NllLossBackward0>)
# tensor(4.3401, grad_fn=<NllLossBackward0>)
# tensor(4.7335, grad_fn=<NllLossBackward0>)
# tensor(4.2308, grad_fn=<NllLossBackward0>)
# tensor(4.5073, grad_fn=<NllLossBackward0>)
# tensor(4.2161, grad_fn=<NllLossBackward0>)
# tensor(4.1488, grad_fn=<NllLossBackward0>)
# tensor(4.5660, grad_fn=<NllLossBackward0>)
# tensor(4.4353, grad_fn=<NllLossBackward0>)
# tensor(4.3014, grad_fn=<NllLossBackward0>)
# tensor(4.3933, grad_fn=<NllLossBackward0>)
# tensor(4.7740, grad_fn=<NllLossBackward0>)
# tensor(4.6592, grad_fn=<NllLossBackward0>)
# tensor(4.4474, grad_fn=<NllLossBackward0>)
# tensor(4.6068, grad_fn=<NllLossBackward0>)
# tensor(4.5692, grad_fn=<NllLossBackward0>)
# tensor(4.4527, grad_fn=<NllLossBackward0>)
# tensor(4.1749, grad_fn=<NllLossBackward0>)
# tensor(4.7120, grad_fn=<NllLossBackward0>)
# tensor(4.3153, grad_fn=<NllLossBackward0>)
# tensor(4.2961, grad_fn=<NllLossBackward0>)
# tensor(4.4312, grad_fn=<NllLossBackward0>)
# tensor(4.5852, grad_fn=<NllLossBackward0>)
# tensor(4.1899, grad_fn=<NllLossBackward0>)
# tensor(4.2442, grad_fn=<NllLossBackward0>)
# tensor(4.5286, grad_fn=<NllLossBackward0>)
# tensor(4.3271, grad_fn=<NllLossBackward0>)
# tensor(4.9594, grad_fn=<NllLossBackward0>)
# tensor(4.5191, grad_fn=<NllLossBackward0>)
# tensor(4.3584, grad_fn=<NllLossBackward0>)
# tensor(4.6081, grad_fn=<NllLossBackward0>)
# tensor(4.5509, grad_fn=<NllLossBackward0>)
# tensor(4.5742, grad_fn=<NllLossBackward0>)
# tensor(4.3236, grad_fn=<NllLossBackward0>)
# tensor(4.3716, grad_fn=<NllLossBackward0>)
# tensor(4.6260, grad_fn=<NllLossBackward0>)
# tensor(4.2830, grad_fn=<NllLossBackward0>)
# tensor(4.7718, grad_fn=<NllLossBackward0>)
# tensor(4.5884, grad_fn=<NllLossBackward0>)
# tensor(4.5981, grad_fn=<NllLossBackward0>)
# tensor(4.3373, grad_fn=<NllLossBackward0>)
# tensor(4.3644, grad_fn=<NllLossBackward0>)
# tensor(4.2287, grad_fn=<NllLossBackward0>)
# tensor(4.3578, grad_fn=<NllLossBackward0>)
# tensor(4.3427, grad_fn=<NllLossBackward0>)
# tensor(4.6466, grad_fn=<NllLossBackward0>)
# tensor(4.5544, grad_fn=<NllLossBackward0>)
# tensor(4.4173, grad_fn=<NllLossBackward0>)
# tensor(4.3175, grad_fn=<NllLossBackward0>)
# tensor(4.5582, grad_fn=<NllLossBackward0>)
# tensor(4.2160, grad_fn=<NllLossBackward0>)
# tensor(4.3239, grad_fn=<NllLossBackward0>)
# tensor(4.3124, grad_fn=<NllLossBackward0>)
# tensor(4.4716, grad_fn=<NllLossBackward0>)
# tensor(4.3715, grad_fn=<NllLossBackward0>)
# tensor(4.3453, grad_fn=<NllLossBackward0>)
# tensor(4.5887, grad_fn=<NllLossBackward0>)
# tensor(4.3678, grad_fn=<NllLossBackward0>)
# tensor(4.4695, grad_fn=<NllLossBackward0>)
# tensor(4.2736, grad_fn=<NllLossBackward0>)
# tensor(4.5846, grad_fn=<NllLossBackward0>)
# tensor(4.4236, grad_fn=<NllLossBackward0>)
# tensor(4.6421, grad_fn=<NllLossBackward0>)
# tensor(4.3686, grad_fn=<NllLossBackward0>)
# tensor(4.3617, grad_fn=<NllLossBackward0>)
# loss: 4.435
# tensor(4.1513, grad_fn=<NllLossBackward0>)
# tensor(4.5588, grad_fn=<NllLossBackward0>)
# tensor(4.4352, grad_fn=<NllLossBackward0>)
# tensor(4.5700, grad_fn=<NllLossBackward0>)
# tensor(4.0141, grad_fn=<NllLossBackward0>)
# tensor(4.4237, grad_fn=<NllLossBackward0>)
# tensor(4.4373, grad_fn=<NllLossBackward0>)
# tensor(4.4013, grad_fn=<NllLossBackward0>)
# tensor(4.3194, grad_fn=<NllLossBackward0>)
# tensor(4.6452, grad_fn=<NllLossBackward0>)
# tensor(4.3387, grad_fn=<NllLossBackward0>)
# tensor(4.6748, grad_fn=<NllLossBackward0>)
# tensor(4.4309, grad_fn=<NllLossBackward0>)
# tensor(4.4695, grad_fn=<NllLossBackward0>)
# tensor(4.3121, grad_fn=<NllLossBackward0>)
# tensor(4.3115, grad_fn=<NllLossBackward0>)
# tensor(4.2689, grad_fn=<NllLossBackward0>)
# tensor(4.5317, grad_fn=<NllLossBackward0>)
# tensor(4.2328, grad_fn=<NllLossBackward0>)
# tensor(4.3086, grad_fn=<NllLossBackward0>)
# tensor(4.1793, grad_fn=<NllLossBackward0>)
# tensor(4.2841, grad_fn=<NllLossBackward0>)
# tensor(4.4806, grad_fn=<NllLossBackward0>)
# tensor(4.5291, grad_fn=<NllLossBackward0>)
# tensor(4.4393, grad_fn=<NllLossBackward0>)
# tensor(4.1835, grad_fn=<NllLossBackward0>)
# tensor(4.3825, grad_fn=<NllLossBackward0>)
# tensor(4.5093, grad_fn=<NllLossBackward0>)
# tensor(4.3585, grad_fn=<NllLossBackward0>)
# tensor(4.2577, grad_fn=<NllLossBackward0>)
# tensor(4.2646, grad_fn=<NllLossBackward0>)
# tensor(4.4242, grad_fn=<NllLossBackward0>)
# tensor(4.5378, grad_fn=<NllLossBackward0>)
# tensor(4.1532, grad_fn=<NllLossBackward0>)
# tensor(4.1993, grad_fn=<NllLossBackward0>)
# tensor(4.4121, grad_fn=<NllLossBackward0>)
# tensor(4.2302, grad_fn=<NllLossBackward0>)
# tensor(4.0762, grad_fn=<NllLossBackward0>)
# tensor(4.5627, grad_fn=<NllLossBackward0>)
# tensor(4.2604, grad_fn=<NllLossBackward0>)
# tensor(4.0964, grad_fn=<NllLossBackward0>)
# tensor(4.5367, grad_fn=<NllLossBackward0>)
# tensor(4.5819, grad_fn=<NllLossBackward0>)
# tensor(4.4800, grad_fn=<NllLossBackward0>)
# tensor(4.4493, grad_fn=<NllLossBackward0>)
# tensor(4.5106, grad_fn=<NllLossBackward0>)
# tensor(4.6024, grad_fn=<NllLossBackward0>)
# tensor(4.4895, grad_fn=<NllLossBackward0>)
# tensor(4.5920, grad_fn=<NllLossBackward0>)
# tensor(4.5354, grad_fn=<NllLossBackward0>)
# tensor(4.2962, grad_fn=<NllLossBackward0>)
# tensor(4.3790, grad_fn=<NllLossBackward0>)
# tensor(4.3976, grad_fn=<NllLossBackward0>)
# tensor(4.2958, grad_fn=<NllLossBackward0>)
# tensor(4.4012, grad_fn=<NllLossBackward0>)
# tensor(4.2907, grad_fn=<NllLossBackward0>)
# tensor(4.2704, grad_fn=<NllLossBackward0>)
# tensor(4.2062, grad_fn=<NllLossBackward0>)
# tensor(4.6299, grad_fn=<NllLossBackward0>)
# tensor(4.6922, grad_fn=<NllLossBackward0>)
# tensor(4.4827, grad_fn=<NllLossBackward0>)
# tensor(4.5298, grad_fn=<NllLossBackward0>)
# tensor(4.6659, grad_fn=<NllLossBackward0>)
# tensor(4.2717, grad_fn=<NllLossBackward0>)
# tensor(4.2170, grad_fn=<NllLossBackward0>)
# tensor(4.3952, grad_fn=<NllLossBackward0>)
# tensor(4.2615, grad_fn=<NllLossBackward0>)
# tensor(4.1840, grad_fn=<NllLossBackward0>)
# tensor(4.1551, grad_fn=<NllLossBackward0>)
# tensor(4.2926, grad_fn=<NllLossBackward0>)
# tensor(4.4577, grad_fn=<NllLossBackward0>)
# tensor(4.2557, grad_fn=<NllLossBackward0>)
# tensor(4.2697, grad_fn=<NllLossBackward0>)
# tensor(4.1221, grad_fn=<NllLossBackward0>)
# tensor(4.4167, grad_fn=<NllLossBackward0>)
# tensor(4.4088, grad_fn=<NllLossBackward0>)
# tensor(4.6530, grad_fn=<NllLossBackward0>)
# tensor(4.4684, grad_fn=<NllLossBackward0>)
# tensor(4.3982, grad_fn=<NllLossBackward0>)
# tensor(4.3649, grad_fn=<NllLossBackward0>)
# tensor(4.2400, grad_fn=<NllLossBackward0>)
# tensor(4.2791, grad_fn=<NllLossBackward0>)
# tensor(4.6174, grad_fn=<NllLossBackward0>)
# tensor(4.1059, grad_fn=<NllLossBackward0>)
# tensor(4.6835, grad_fn=<NllLossBackward0>)
# tensor(4.2892, grad_fn=<NllLossBackward0>)
# tensor(4.4016, grad_fn=<NllLossBackward0>)
# tensor(4.5108, grad_fn=<NllLossBackward0>)
# tensor(4.0476, grad_fn=<NllLossBackward0>)
# tensor(4.5446, grad_fn=<NllLossBackward0>)
# tensor(4.6229, grad_fn=<NllLossBackward0>)
# tensor(4.3557, grad_fn=<NllLossBackward0>)
# tensor(4.2183, grad_fn=<NllLossBackward0>)
# tensor(4.5406, grad_fn=<NllLossBackward0>)
# tensor(4.2091, grad_fn=<NllLossBackward0>)
# tensor(4.2583, grad_fn=<NllLossBackward0>)
# tensor(4.6329, grad_fn=<NllLossBackward0>)
# tensor(4.5387, grad_fn=<NllLossBackward0>)
# tensor(4.4869, grad_fn=<NllLossBackward0>)
# tensor(4.3744, grad_fn=<NllLossBackward0>)
# loss: 4.386
# tensor(4.2416, grad_fn=<NllLossBackward0>)
# tensor(4.5600, grad_fn=<NllLossBackward0>)
# tensor(4.3390, grad_fn=<NllLossBackward0>)
# tensor(4.3041, grad_fn=<NllLossBackward0>)
# tensor(4.3780, grad_fn=<NllLossBackward0>)
# tensor(4.4400, grad_fn=<NllLossBackward0>)
# tensor(4.3703, grad_fn=<NllLossBackward0>)
# tensor(4.5010, grad_fn=<NllLossBackward0>)
# tensor(4.3775, grad_fn=<NllLossBackward0>)
# tensor(4.3714, grad_fn=<NllLossBackward0>)
# tensor(4.1896, grad_fn=<NllLossBackward0>)
# tensor(4.3486, grad_fn=<NllLossBackward0>)
# tensor(4.2361, grad_fn=<NllLossBackward0>)
# tensor(4.2793, grad_fn=<NllLossBackward0>)
# tensor(4.2568, grad_fn=<NllLossBackward0>)
# tensor(4.3761, grad_fn=<NllLossBackward0>)
# tensor(4.4722, grad_fn=<NllLossBackward0>)
# tensor(4.5789, grad_fn=<NllLossBackward0>)
# tensor(4.4164, grad_fn=<NllLossBackward0>)
# tensor(4.5207, grad_fn=<NllLossBackward0>)
# tensor(4.2155, grad_fn=<NllLossBackward0>)
# tensor(4.3538, grad_fn=<NllLossBackward0>)
# tensor(4.5649, grad_fn=<NllLossBackward0>)
# tensor(4.5061, grad_fn=<NllLossBackward0>)
# tensor(4.2659, grad_fn=<NllLossBackward0>)
# tensor(4.2715, grad_fn=<NllLossBackward0>)
# tensor(4.5674, grad_fn=<NllLossBackward0>)
# tensor(4.1525, grad_fn=<NllLossBackward0>)
# tensor(4.3962, grad_fn=<NllLossBackward0>)
# tensor(4.5035, grad_fn=<NllLossBackward0>)
# tensor(4.4424, grad_fn=<NllLossBackward0>)
# tensor(4.1409, grad_fn=<NllLossBackward0>)
# tensor(4.2605, grad_fn=<NllLossBackward0>)
# tensor(4.5941, grad_fn=<NllLossBackward0>)
# tensor(4.1564, grad_fn=<NllLossBackward0>)
# tensor(4.4658, grad_fn=<NllLossBackward0>)
# tensor(4.3027, grad_fn=<NllLossBackward0>)
# tensor(4.5872, grad_fn=<NllLossBackward0>)
# tensor(4.5251, grad_fn=<NllLossBackward0>)
# tensor(4.0859, grad_fn=<NllLossBackward0>)
# tensor(4.1736, grad_fn=<NllLossBackward0>)
# tensor(4.4173, grad_fn=<NllLossBackward0>)
# tensor(4.4624, grad_fn=<NllLossBackward0>)
# tensor(4.5086, grad_fn=<NllLossBackward0>)
# tensor(4.4670, grad_fn=<NllLossBackward0>)
# tensor(4.0828, grad_fn=<NllLossBackward0>)
# tensor(4.6131, grad_fn=<NllLossBackward0>)
# tensor(4.4731, grad_fn=<NllLossBackward0>)
# tensor(4.7693, grad_fn=<NllLossBackward0>)
# tensor(3.9785, grad_fn=<NllLossBackward0>)
# tensor(4.3851, grad_fn=<NllLossBackward0>)
# tensor(4.0963, grad_fn=<NllLossBackward0>)
# tensor(4.2670, grad_fn=<NllLossBackward0>)
# tensor(4.2695, grad_fn=<NllLossBackward0>)
# tensor(4.1939, grad_fn=<NllLossBackward0>)
# tensor(4.3145, grad_fn=<NllLossBackward0>)
# tensor(4.3169, grad_fn=<NllLossBackward0>)
# tensor(4.2198, grad_fn=<NllLossBackward0>)
# tensor(4.5211, grad_fn=<NllLossBackward0>)
# tensor(4.4102, grad_fn=<NllLossBackward0>)
# tensor(4.3532, grad_fn=<NllLossBackward0>)
# tensor(4.2552, grad_fn=<NllLossBackward0>)
# tensor(4.2965, grad_fn=<NllLossBackward0>)
# tensor(4.5041, grad_fn=<NllLossBackward0>)
# tensor(4.5099, grad_fn=<NllLossBackward0>)
# tensor(4.4883, grad_fn=<NllLossBackward0>)
# tensor(4.1905, grad_fn=<NllLossBackward0>)
# tensor(4.3868, grad_fn=<NllLossBackward0>)
# tensor(4.3560, grad_fn=<NllLossBackward0>)
# tensor(4.4480, grad_fn=<NllLossBackward0>)
# tensor(4.4786, grad_fn=<NllLossBackward0>)
# tensor(4.1884, grad_fn=<NllLossBackward0>)
# tensor(4.6404, grad_fn=<NllLossBackward0>)
# tensor(4.2634, grad_fn=<NllLossBackward0>)
# tensor(4.2320, grad_fn=<NllLossBackward0>)
# tensor(4.3855, grad_fn=<NllLossBackward0>)
# tensor(4.1314, grad_fn=<NllLossBackward0>)
# tensor(4.4416, grad_fn=<NllLossBackward0>)
# tensor(4.3412, grad_fn=<NllLossBackward0>)
# tensor(4.5705, grad_fn=<NllLossBackward0>)
# tensor(4.3410, grad_fn=<NllLossBackward0>)
# tensor(4.4180, grad_fn=<NllLossBackward0>)
# tensor(4.2027, grad_fn=<NllLossBackward0>)
# tensor(4.3700, grad_fn=<NllLossBackward0>)
# tensor(4.3782, grad_fn=<NllLossBackward0>)
# tensor(4.4753, grad_fn=<NllLossBackward0>)
# tensor(4.2048, grad_fn=<NllLossBackward0>)
# tensor(3.8939, grad_fn=<NllLossBackward0>)
# tensor(4.5459, grad_fn=<NllLossBackward0>)
# tensor(4.3558, grad_fn=<NllLossBackward0>)
# tensor(4.2421, grad_fn=<NllLossBackward0>)
# tensor(4.2963, grad_fn=<NllLossBackward0>)
# tensor(4.5161, grad_fn=<NllLossBackward0>)
# tensor(4.3910, grad_fn=<NllLossBackward0>)
# tensor(4.0536, grad_fn=<NllLossBackward0>)
# tensor(4.2710, grad_fn=<NllLossBackward0>)
# tensor(4.4558, grad_fn=<NllLossBackward0>)
# tensor(4.3440, grad_fn=<NllLossBackward0>)
# tensor(4.3357, grad_fn=<NllLossBackward0>)
# tensor(4.5822, grad_fn=<NllLossBackward0>)
# loss: 4.362
# tensor(4.4089, grad_fn=<NllLossBackward0>)
# tensor(4.2922, grad_fn=<NllLossBackward0>)
# tensor(4.3324, grad_fn=<NllLossBackward0>)
# tensor(4.2382, grad_fn=<NllLossBackward0>)
# tensor(4.5239, grad_fn=<NllLossBackward0>)
# tensor(4.2688, grad_fn=<NllLossBackward0>)
# tensor(4.2248, grad_fn=<NllLossBackward0>)
# tensor(4.2632, grad_fn=<NllLossBackward0>)
# tensor(4.2986, grad_fn=<NllLossBackward0>)
# tensor(4.0392, grad_fn=<NllLossBackward0>)
# tensor(4.2075, grad_fn=<NllLossBackward0>)
# tensor(4.2296, grad_fn=<NllLossBackward0>)
# tensor(4.1632, grad_fn=<NllLossBackward0>)
# tensor(4.3057, grad_fn=<NllLossBackward0>)
# tensor(4.5337, grad_fn=<NllLossBackward0>)
# tensor(4.1441, grad_fn=<NllLossBackward0>)
# tensor(4.1835, grad_fn=<NllLossBackward0>)
# tensor(4.1868, grad_fn=<NllLossBackward0>)
# tensor(4.2670, grad_fn=<NllLossBackward0>)
# tensor(4.5180, grad_fn=<NllLossBackward0>)
# tensor(4.5382, grad_fn=<NllLossBackward0>)
# tensor(4.5361, grad_fn=<NllLossBackward0>)
# tensor(4.2189, grad_fn=<NllLossBackward0>)
# tensor(4.1387, grad_fn=<NllLossBackward0>)
# tensor(4.4486, grad_fn=<NllLossBackward0>)
# tensor(4.1357, grad_fn=<NllLossBackward0>)
# tensor(4.1955, grad_fn=<NllLossBackward0>)
# tensor(4.3293, grad_fn=<NllLossBackward0>)
# tensor(4.1718, grad_fn=<NllLossBackward0>)
# tensor(4.4841, grad_fn=<NllLossBackward0>)
# tensor(4.2579, grad_fn=<NllLossBackward0>)
# tensor(4.4531, grad_fn=<NllLossBackward0>)
# tensor(4.5702, grad_fn=<NllLossBackward0>)
# tensor(4.4145, grad_fn=<NllLossBackward0>)
# tensor(4.2382, grad_fn=<NllLossBackward0>)
# tensor(4.0866, grad_fn=<NllLossBackward0>)
# tensor(4.3397, grad_fn=<NllLossBackward0>)
# tensor(4.1539, grad_fn=<NllLossBackward0>)
# tensor(4.2846, grad_fn=<NllLossBackward0>)
# tensor(3.9999, grad_fn=<NllLossBackward0>)
# tensor(4.1862, grad_fn=<NllLossBackward0>)
# tensor(4.1799, grad_fn=<NllLossBackward0>)
# tensor(4.3189, grad_fn=<NllLossBackward0>)
# tensor(4.5204, grad_fn=<NllLossBackward0>)
# tensor(4.5768, grad_fn=<NllLossBackward0>)
# tensor(4.2931, grad_fn=<NllLossBackward0>)
# tensor(4.0294, grad_fn=<NllLossBackward0>)
# tensor(4.2323, grad_fn=<NllLossBackward0>)
# tensor(4.3351, grad_fn=<NllLossBackward0>)
# tensor(4.5644, grad_fn=<NllLossBackward0>)
# tensor(4.4540, grad_fn=<NllLossBackward0>)
# tensor(4.2456, grad_fn=<NllLossBackward0>)
# tensor(4.5756, grad_fn=<NllLossBackward0>)
# tensor(4.2445, grad_fn=<NllLossBackward0>)
# tensor(4.2347, grad_fn=<NllLossBackward0>)
# tensor(4.3623, grad_fn=<NllLossBackward0>)
# tensor(4.1685, grad_fn=<NllLossBackward0>)
# tensor(4.3001, grad_fn=<NllLossBackward0>)
# tensor(4.6028, grad_fn=<NllLossBackward0>)
# tensor(4.4731, grad_fn=<NllLossBackward0>)
# tensor(4.2360, grad_fn=<NllLossBackward0>)
# tensor(4.4203, grad_fn=<NllLossBackward0>)
# tensor(4.3885, grad_fn=<NllLossBackward0>)
# tensor(4.4321, grad_fn=<NllLossBackward0>)
# tensor(4.2963, grad_fn=<NllLossBackward0>)
# tensor(4.2391, grad_fn=<NllLossBackward0>)
# tensor(4.3795, grad_fn=<NllLossBackward0>)
# tensor(4.2515, grad_fn=<NllLossBackward0>)
# tensor(4.5103, grad_fn=<NllLossBackward0>)
# tensor(4.3158, grad_fn=<NllLossBackward0>)
# tensor(4.2086, grad_fn=<NllLossBackward0>)
# tensor(4.4536, grad_fn=<NllLossBackward0>)
# tensor(3.9932, grad_fn=<NllLossBackward0>)
# tensor(4.0920, grad_fn=<NllLossBackward0>)
# tensor(4.3895, grad_fn=<NllLossBackward0>)
# tensor(4.2807, grad_fn=<NllLossBackward0>)
# tensor(4.4386, grad_fn=<NllLossBackward0>)
# tensor(4.3316, grad_fn=<NllLossBackward0>)
# tensor(4.6639, grad_fn=<NllLossBackward0>)
# tensor(4.5095, grad_fn=<NllLossBackward0>)
# tensor(4.3064, grad_fn=<NllLossBackward0>)
# tensor(4.2956, grad_fn=<NllLossBackward0>)
# tensor(4.3670, grad_fn=<NllLossBackward0>)
# tensor(4.3747, grad_fn=<NllLossBackward0>)
# tensor(3.8337, grad_fn=<NllLossBackward0>)
# tensor(4.3826, grad_fn=<NllLossBackward0>)
# tensor(4.4422, grad_fn=<NllLossBackward0>)
# tensor(4.0821, grad_fn=<NllLossBackward0>)
# tensor(4.5046, grad_fn=<NllLossBackward0>)
# tensor(4.5334, grad_fn=<NllLossBackward0>)
# tensor(4.3134, grad_fn=<NllLossBackward0>)
# tensor(4.2978, grad_fn=<NllLossBackward0>)
# tensor(4.4158, grad_fn=<NllLossBackward0>)
# tensor(4.0926, grad_fn=<NllLossBackward0>)
# tensor(4.2540, grad_fn=<NllLossBackward0>)
# tensor(4.4530, grad_fn=<NllLossBackward0>)
# tensor(4.2994, grad_fn=<NllLossBackward0>)
# tensor(4.0869, grad_fn=<NllLossBackward0>)
# tensor(4.1043, grad_fn=<NllLossBackward0>)
# tensor(4.8886, grad_fn=<NllLossBackward0>)
# loss: 4.319
# tensor(4.6214, grad_fn=<NllLossBackward0>)
# tensor(4.2189, grad_fn=<NllLossBackward0>)
# tensor(4.2766, grad_fn=<NllLossBackward0>)
# tensor(4.2865, grad_fn=<NllLossBackward0>)
# tensor(4.4296, grad_fn=<NllLossBackward0>)
# tensor(4.5160, grad_fn=<NllLossBackward0>)
# tensor(4.0975, grad_fn=<NllLossBackward0>)
# tensor(4.3739, grad_fn=<NllLossBackward0>)
# tensor(4.2194, grad_fn=<NllLossBackward0>)
# tensor(4.1762, grad_fn=<NllLossBackward0>)
# tensor(4.1736, grad_fn=<NllLossBackward0>)
# tensor(4.3651, grad_fn=<NllLossBackward0>)
# tensor(4.1228, grad_fn=<NllLossBackward0>)
# tensor(4.0799, grad_fn=<NllLossBackward0>)
# tensor(4.2203, grad_fn=<NllLossBackward0>)
# tensor(4.3475, grad_fn=<NllLossBackward0>)
# tensor(4.2996, grad_fn=<NllLossBackward0>)
# tensor(4.1638, grad_fn=<NllLossBackward0>)
# tensor(4.1249, grad_fn=<NllLossBackward0>)
# tensor(3.9932, grad_fn=<NllLossBackward0>)
# tensor(4.2453, grad_fn=<NllLossBackward0>)
# tensor(4.5337, grad_fn=<NllLossBackward0>)
# tensor(4.5175, grad_fn=<NllLossBackward0>)
# tensor(4.5320, grad_fn=<NllLossBackward0>)
# tensor(4.3769, grad_fn=<NllLossBackward0>)
# tensor(4.2407, grad_fn=<NllLossBackward0>)
# tensor(4.4056, grad_fn=<NllLossBackward0>)
# tensor(4.4689, grad_fn=<NllLossBackward0>)
# tensor(4.0683, grad_fn=<NllLossBackward0>)
# tensor(4.0767, grad_fn=<NllLossBackward0>)
# tensor(4.7333, grad_fn=<NllLossBackward0>)
# tensor(4.3088, grad_fn=<NllLossBackward0>)
# tensor(4.3979, grad_fn=<NllLossBackward0>)
# tensor(4.1730, grad_fn=<NllLossBackward0>)
# tensor(4.5101, grad_fn=<NllLossBackward0>)
# tensor(4.4353, grad_fn=<NllLossBackward0>)
# tensor(4.2898, grad_fn=<NllLossBackward0>)
# tensor(4.3693, grad_fn=<NllLossBackward0>)
# tensor(4.4092, grad_fn=<NllLossBackward0>)
# tensor(4.5721, grad_fn=<NllLossBackward0>)
# tensor(4.3812, grad_fn=<NllLossBackward0>)
# tensor(4.3813, grad_fn=<NllLossBackward0>)
# tensor(4.2126, grad_fn=<NllLossBackward0>)
# tensor(4.1926, grad_fn=<NllLossBackward0>)
# tensor(4.3950, grad_fn=<NllLossBackward0>)
# tensor(4.0899, grad_fn=<NllLossBackward0>)
# tensor(4.2761, grad_fn=<NllLossBackward0>)
# tensor(4.2204, grad_fn=<NllLossBackward0>)
# tensor(4.5968, grad_fn=<NllLossBackward0>)
# tensor(4.2831, grad_fn=<NllLossBackward0>)
# tensor(4.4519, grad_fn=<NllLossBackward0>)
# tensor(4.1873, grad_fn=<NllLossBackward0>)
# tensor(4.6519, grad_fn=<NllLossBackward0>)
# tensor(3.7837, grad_fn=<NllLossBackward0>)
# tensor(4.0968, grad_fn=<NllLossBackward0>)
# tensor(4.2254, grad_fn=<NllLossBackward0>)
# tensor(4.1111, grad_fn=<NllLossBackward0>)
# tensor(4.1586, grad_fn=<NllLossBackward0>)
# tensor(4.5219, grad_fn=<NllLossBackward0>)
# tensor(4.2627, grad_fn=<NllLossBackward0>)
# tensor(4.1314, grad_fn=<NllLossBackward0>)
# tensor(4.5130, grad_fn=<NllLossBackward0>)
# tensor(4.1080, grad_fn=<NllLossBackward0>)
# tensor(4.3936, grad_fn=<NllLossBackward0>)
# tensor(4.2079, grad_fn=<NllLossBackward0>)
# tensor(4.1506, grad_fn=<NllLossBackward0>)
# tensor(4.2150, grad_fn=<NllLossBackward0>)
# tensor(4.3529, grad_fn=<NllLossBackward0>)
# tensor(4.2561, grad_fn=<NllLossBackward0>)
# tensor(4.3413, grad_fn=<NllLossBackward0>)
# tensor(4.0165, grad_fn=<NllLossBackward0>)
# tensor(4.0910, grad_fn=<NllLossBackward0>)
# tensor(4.2897, grad_fn=<NllLossBackward0>)
# tensor(4.0504, grad_fn=<NllLossBackward0>)
# tensor(4.1643, grad_fn=<NllLossBackward0>)
# tensor(4.0448, grad_fn=<NllLossBackward0>)
# tensor(3.9797, grad_fn=<NllLossBackward0>)
# tensor(4.1758, grad_fn=<NllLossBackward0>)
# tensor(4.2923, grad_fn=<NllLossBackward0>)
# tensor(4.2649, grad_fn=<NllLossBackward0>)
# tensor(4.2944, grad_fn=<NllLossBackward0>)
# tensor(4.4587, grad_fn=<NllLossBackward0>)
# tensor(4.1393, grad_fn=<NllLossBackward0>)
# tensor(4.2354, grad_fn=<NllLossBackward0>)
# tensor(4.1619, grad_fn=<NllLossBackward0>)
# tensor(4.2852, grad_fn=<NllLossBackward0>)
# tensor(4.4513, grad_fn=<NllLossBackward0>)
# tensor(4.2183, grad_fn=<NllLossBackward0>)
# tensor(4.0266, grad_fn=<NllLossBackward0>)
# tensor(4.3432, grad_fn=<NllLossBackward0>)
# tensor(4.3866, grad_fn=<NllLossBackward0>)
# tensor(4.1681, grad_fn=<NllLossBackward0>)
# tensor(4.1559, grad_fn=<NllLossBackward0>)
# tensor(4.3159, grad_fn=<NllLossBackward0>)
# tensor(4.3018, grad_fn=<NllLossBackward0>)
# tensor(4.3094, grad_fn=<NllLossBackward0>)
# tensor(4.2266, grad_fn=<NllLossBackward0>)
# tensor(4.3629, grad_fn=<NllLossBackward0>)
# tensor(4.0027, grad_fn=<NllLossBackward0>)
# tensor(4.4612, grad_fn=<NllLossBackward0>)
# loss: 4.271
# tensor(4.1135, grad_fn=<NllLossBackward0>)
# tensor(4.2544, grad_fn=<NllLossBackward0>)
# tensor(4.3770, grad_fn=<NllLossBackward0>)
# tensor(4.3722, grad_fn=<NllLossBackward0>)
# tensor(4.0347, grad_fn=<NllLossBackward0>)
# tensor(4.3878, grad_fn=<NllLossBackward0>)
# tensor(4.3378, grad_fn=<NllLossBackward0>)
# tensor(4.0221, grad_fn=<NllLossBackward0>)
# tensor(4.2609, grad_fn=<NllLossBackward0>)
# tensor(4.3135, grad_fn=<NllLossBackward0>)
# tensor(4.0034, grad_fn=<NllLossBackward0>)
# tensor(4.4146, grad_fn=<NllLossBackward0>)
# tensor(4.3544, grad_fn=<NllLossBackward0>)
# tensor(4.3585, grad_fn=<NllLossBackward0>)
# tensor(4.3018, grad_fn=<NllLossBackward0>)
# tensor(4.0159, grad_fn=<NllLossBackward0>)
# tensor(4.0524, grad_fn=<NllLossBackward0>)
# tensor(4.1480, grad_fn=<NllLossBackward0>)
# tensor(4.2489, grad_fn=<NllLossBackward0>)
# tensor(4.1763, grad_fn=<NllLossBackward0>)
# tensor(4.3267, grad_fn=<NllLossBackward0>)
# tensor(4.1453, grad_fn=<NllLossBackward0>)
# tensor(4.1534, grad_fn=<NllLossBackward0>)
# tensor(4.6902, grad_fn=<NllLossBackward0>)
# tensor(4.1143, grad_fn=<NllLossBackward0>)
# tensor(4.4662, grad_fn=<NllLossBackward0>)
# tensor(4.3979, grad_fn=<NllLossBackward0>)
# tensor(4.2975, grad_fn=<NllLossBackward0>)
# tensor(4.3223, grad_fn=<NllLossBackward0>)
# tensor(4.1936, grad_fn=<NllLossBackward0>)
# tensor(4.1287, grad_fn=<NllLossBackward0>)
# tensor(4.2323, grad_fn=<NllLossBackward0>)
# tensor(4.2120, grad_fn=<NllLossBackward0>)
# tensor(4.0758, grad_fn=<NllLossBackward0>)
# tensor(4.3813, grad_fn=<NllLossBackward0>)
# tensor(4.1367, grad_fn=<NllLossBackward0>)
# tensor(4.3039, grad_fn=<NllLossBackward0>)
# tensor(4.3248, grad_fn=<NllLossBackward0>)
# tensor(4.1233, grad_fn=<NllLossBackward0>)
# tensor(4.1898, grad_fn=<NllLossBackward0>)
# tensor(4.2713, grad_fn=<NllLossBackward0>)
# tensor(4.2391, grad_fn=<NllLossBackward0>)
# tensor(4.4596, grad_fn=<NllLossBackward0>)
# tensor(4.1544, grad_fn=<NllLossBackward0>)
# tensor(4.3501, grad_fn=<NllLossBackward0>)
# tensor(4.2988, grad_fn=<NllLossBackward0>)
# tensor(4.3692, grad_fn=<NllLossBackward0>)
# tensor(4.4932, grad_fn=<NllLossBackward0>)
# tensor(4.1597, grad_fn=<NllLossBackward0>)
# tensor(4.1767, grad_fn=<NllLossBackward0>)
# tensor(4.3910, grad_fn=<NllLossBackward0>)
# tensor(4.3882, grad_fn=<NllLossBackward0>)
# tensor(4.0196, grad_fn=<NllLossBackward0>)
# tensor(4.2815, grad_fn=<NllLossBackward0>)
# tensor(4.3761, grad_fn=<NllLossBackward0>)
# tensor(4.2733, grad_fn=<NllLossBackward0>)
# tensor(4.3703, grad_fn=<NllLossBackward0>)
# tensor(4.4425, grad_fn=<NllLossBackward0>)
# tensor(4.4744, grad_fn=<NllLossBackward0>)
# tensor(3.8728, grad_fn=<NllLossBackward0>)
# tensor(4.2226, grad_fn=<NllLossBackward0>)
# tensor(4.3531, grad_fn=<NllLossBackward0>)
# tensor(4.0773, grad_fn=<NllLossBackward0>)
# tensor(4.2470, grad_fn=<NllLossBackward0>)
# tensor(4.1435, grad_fn=<NllLossBackward0>)
# tensor(3.7143, grad_fn=<NllLossBackward0>)
# tensor(3.9796, grad_fn=<NllLossBackward0>)
# tensor(4.1338, grad_fn=<NllLossBackward0>)
# tensor(4.1673, grad_fn=<NllLossBackward0>)
# tensor(4.4019, grad_fn=<NllLossBackward0>)
# tensor(4.0655, grad_fn=<NllLossBackward0>)
# tensor(4.1653, grad_fn=<NllLossBackward0>)
# tensor(4.3497, grad_fn=<NllLossBackward0>)
# tensor(4.1940, grad_fn=<NllLossBackward0>)
# tensor(4.0021, grad_fn=<NllLossBackward0>)
# tensor(4.2586, grad_fn=<NllLossBackward0>)
# tensor(4.2372, grad_fn=<NllLossBackward0>)
# tensor(4.2283, grad_fn=<NllLossBackward0>)
# tensor(4.3060, grad_fn=<NllLossBackward0>)
# tensor(4.2287, grad_fn=<NllLossBackward0>)
# tensor(4.2391, grad_fn=<NllLossBackward0>)
# tensor(4.4447, grad_fn=<NllLossBackward0>)
# tensor(4.1144, grad_fn=<NllLossBackward0>)
# tensor(4.0260, grad_fn=<NllLossBackward0>)
# tensor(4.2160, grad_fn=<NllLossBackward0>)
# tensor(4.3045, grad_fn=<NllLossBackward0>)
# tensor(4.1184, grad_fn=<NllLossBackward0>)
# tensor(3.9415, grad_fn=<NllLossBackward0>)
# tensor(4.2681, grad_fn=<NllLossBackward0>)
# tensor(4.2607, grad_fn=<NllLossBackward0>)
# tensor(4.3630, grad_fn=<NllLossBackward0>)
# tensor(4.1671, grad_fn=<NllLossBackward0>)
# tensor(3.9699, grad_fn=<NllLossBackward0>)
# tensor(4.0554, grad_fn=<NllLossBackward0>)
# tensor(4.0461, grad_fn=<NllLossBackward0>)
# tensor(3.8802, grad_fn=<NllLossBackward0>)
# tensor(4.2505, grad_fn=<NllLossBackward0>)
# tensor(4.1389, grad_fn=<NllLossBackward0>)
# tensor(4.2109, grad_fn=<NllLossBackward0>)
# tensor(4.2651, grad_fn=<NllLossBackward0>)
# loss: 4.225
# tensor(4.2490, grad_fn=<NllLossBackward0>)
# tensor(4.4841, grad_fn=<NllLossBackward0>)
# tensor(4.4055, grad_fn=<NllLossBackward0>)
# tensor(3.9584, grad_fn=<NllLossBackward0>)
# tensor(4.2431, grad_fn=<NllLossBackward0>)
# tensor(4.1419, grad_fn=<NllLossBackward0>)
# tensor(4.1319, grad_fn=<NllLossBackward0>)
# tensor(4.4568, grad_fn=<NllLossBackward0>)
# tensor(4.1610, grad_fn=<NllLossBackward0>)
# tensor(3.9436, grad_fn=<NllLossBackward0>)
# tensor(4.3301, grad_fn=<NllLossBackward0>)
# tensor(4.3362, grad_fn=<NllLossBackward0>)
# tensor(4.0240, grad_fn=<NllLossBackward0>)
# tensor(4.3314, grad_fn=<NllLossBackward0>)
# tensor(4.1263, grad_fn=<NllLossBackward0>)
# tensor(3.9895, grad_fn=<NllLossBackward0>)
# tensor(4.1413, grad_fn=<NllLossBackward0>)
# tensor(4.0977, grad_fn=<NllLossBackward0>)
# tensor(4.2153, grad_fn=<NllLossBackward0>)
# tensor(4.2442, grad_fn=<NllLossBackward0>)
# tensor(4.2482, grad_fn=<NllLossBackward0>)
# tensor(4.2128, grad_fn=<NllLossBackward0>)
# tensor(4.4381, grad_fn=<NllLossBackward0>)
# tensor(4.1759, grad_fn=<NllLossBackward0>)
# tensor(4.2247, grad_fn=<NllLossBackward0>)
# tensor(4.3673, grad_fn=<NllLossBackward0>)
# tensor(3.9317, grad_fn=<NllLossBackward0>)
# tensor(4.3632, grad_fn=<NllLossBackward0>)
# tensor(4.1689, grad_fn=<NllLossBackward0>)
# tensor(4.2126, grad_fn=<NllLossBackward0>)
# tensor(4.2585, grad_fn=<NllLossBackward0>)
# tensor(4.2751, grad_fn=<NllLossBackward0>)
# tensor(4.0274, grad_fn=<NllLossBackward0>)
# tensor(4.3145, grad_fn=<NllLossBackward0>)
# tensor(4.4457, grad_fn=<NllLossBackward0>)
# tensor(4.1648, grad_fn=<NllLossBackward0>)
# tensor(4.5116, grad_fn=<NllLossBackward0>)
# tensor(4.0681, grad_fn=<NllLossBackward0>)
# tensor(4.2931, grad_fn=<NllLossBackward0>)
# tensor(4.1945, grad_fn=<NllLossBackward0>)
# tensor(4.3955, grad_fn=<NllLossBackward0>)
# tensor(4.0299, grad_fn=<NllLossBackward0>)
# tensor(4.1982, grad_fn=<NllLossBackward0>)
# tensor(4.2141, grad_fn=<NllLossBackward0>)
# tensor(4.1844, grad_fn=<NllLossBackward0>)
# tensor(4.0374, grad_fn=<NllLossBackward0>)
# tensor(4.1742, grad_fn=<NllLossBackward0>)
# tensor(4.1025, grad_fn=<NllLossBackward0>)
# tensor(4.2385, grad_fn=<NllLossBackward0>)
# tensor(4.3360, grad_fn=<NllLossBackward0>)
# tensor(4.0015, grad_fn=<NllLossBackward0>)
# tensor(4.2526, grad_fn=<NllLossBackward0>)
# tensor(4.3286, grad_fn=<NllLossBackward0>)
# tensor(4.4825, grad_fn=<NllLossBackward0>)
# tensor(4.4849, grad_fn=<NllLossBackward0>)
# tensor(4.4129, grad_fn=<NllLossBackward0>)
# tensor(4.2728, grad_fn=<NllLossBackward0>)
# tensor(4.4134, grad_fn=<NllLossBackward0>)
# tensor(4.4072, grad_fn=<NllLossBackward0>)
# tensor(4.2200, grad_fn=<NllLossBackward0>)
# tensor(4.0527, grad_fn=<NllLossBackward0>)
# tensor(4.2361, grad_fn=<NllLossBackward0>)
# tensor(4.2121, grad_fn=<NllLossBackward0>)
# tensor(4.1595, grad_fn=<NllLossBackward0>)
# tensor(4.5901, grad_fn=<NllLossBackward0>)
# tensor(4.3533, grad_fn=<NllLossBackward0>)
# tensor(4.3702, grad_fn=<NllLossBackward0>)
# tensor(4.2678, grad_fn=<NllLossBackward0>)
# tensor(4.0912, grad_fn=<NllLossBackward0>)
# tensor(4.0682, grad_fn=<NllLossBackward0>)
# tensor(4.3492, grad_fn=<NllLossBackward0>)
# tensor(4.0886, grad_fn=<NllLossBackward0>)
# tensor(4.0913, grad_fn=<NllLossBackward0>)
# tensor(4.2078, grad_fn=<NllLossBackward0>)
# tensor(4.5062, grad_fn=<NllLossBackward0>)
# tensor(4.0274, grad_fn=<NllLossBackward0>)
# tensor(4.4114, grad_fn=<NllLossBackward0>)
# tensor(3.9104, grad_fn=<NllLossBackward0>)
# tensor(4.1392, grad_fn=<NllLossBackward0>)
# tensor(4.0836, grad_fn=<NllLossBackward0>)
# tensor(4.2291, grad_fn=<NllLossBackward0>)
# tensor(4.0835, grad_fn=<NllLossBackward0>)
# tensor(4.2921, grad_fn=<NllLossBackward0>)
# tensor(3.9602, grad_fn=<NllLossBackward0>)
# tensor(3.8182, grad_fn=<NllLossBackward0>)
# tensor(3.9720, grad_fn=<NllLossBackward0>)
# tensor(4.3661, grad_fn=<NllLossBackward0>)
# tensor(4.1760, grad_fn=<NllLossBackward0>)
# tensor(4.3108, grad_fn=<NllLossBackward0>)
# tensor(4.2703, grad_fn=<NllLossBackward0>)
# tensor(4.1540, grad_fn=<NllLossBackward0>)
# tensor(4.1797, grad_fn=<NllLossBackward0>)
# tensor(4.0215, grad_fn=<NllLossBackward0>)
# tensor(4.2499, grad_fn=<NllLossBackward0>)
# tensor(4.3442, grad_fn=<NllLossBackward0>)
# tensor(4.1761, grad_fn=<NllLossBackward0>)
# tensor(4.3829, grad_fn=<NllLossBackward0>)
# tensor(4.2190, grad_fn=<NllLossBackward0>)
# tensor(4.2058, grad_fn=<NllLossBackward0>)
# tensor(4.2311, grad_fn=<NllLossBackward0>)
# loss: 4.219
# tensor(4.1565, grad_fn=<NllLossBackward0>)
# tensor(4.7637, grad_fn=<NllLossBackward0>)
# tensor(4.3487, grad_fn=<NllLossBackward0>)
# tensor(4.3023, grad_fn=<NllLossBackward0>)
# tensor(4.0258, grad_fn=<NllLossBackward0>)
# tensor(4.3000, grad_fn=<NllLossBackward0>)
# tensor(4.1053, grad_fn=<NllLossBackward0>)
# tensor(4.1687, grad_fn=<NllLossBackward0>)
# tensor(4.0879, grad_fn=<NllLossBackward0>)
# tensor(4.0526, grad_fn=<NllLossBackward0>)
# tensor(4.1204, grad_fn=<NllLossBackward0>)
# tensor(3.9960, grad_fn=<NllLossBackward0>)
# tensor(3.9260, grad_fn=<NllLossBackward0>)
# tensor(3.8621, grad_fn=<NllLossBackward0>)
# ...
# tensor(3.6897, grad_fn=<NllLossBackward0>)
# loss: 4.028
# tensor(3.6683, grad_fn=<NllLossBackward0>)
# tensor(3.7807, grad_fn=<NllLossBackward0>)
# tensor(3.9470, grad_fn=<NllLossBackward0>)
# tensor(4.0656, grad_fn=<NllLossBackward0>)
# tensor(3.6019, grad_fn=<NllLossBackward0>)
# tensor(3.9886, grad_fn=<NllLossBackward0>)
# tensor(3.9436, grad_fn=<NllLossBackward0>)
# tensor(3.4811, grad_fn=<NllLossBackward0>)
# tensor(4.1582, grad_fn=<NllLossBackward0>)
# tensor(4.0232, grad_fn=<NllLossBackward0>)
# tensor(4.2354, grad_fn=<NllLossBackward0>)
# tensor(4.0839, grad_fn=<NllLossBackward0>)
# tensor(4.1561, grad_fn=<NllLossBackward0>)
# tensor(4.2276, grad_fn=<NllLossBackward0>)
# tensor(4.1238, grad_fn=<NllLossBackward0>)
# tensor(3.8117, grad_fn=<NllLossBackward0>)
# tensor(3.7992, grad_fn=<NllLossBackward0>)
# tensor(3.6765, grad_fn=<NllLossBackward0>)
# tensor(4.0318, grad_fn=<NllLossBackward0>)
# tensor(4.4473, grad_fn=<NllLossBackward0>)
# tensor(4.0472, grad_fn=<NllLossBackward0>)
# tensor(3.6391, grad_fn=<NllLossBackward0>)
# tensor(3.8918, grad_fn=<NllLossBackward0>)
# tensor(4.1393, grad_fn=<NllLossBackward0>)
# tensor(4.1038, grad_fn=<NllLossBackward0>)
# tensor(3.9927, grad_fn=<NllLossBackward0>)
# tensor(4.0234, grad_fn=<NllLossBackward0>)
# tensor(3.7616, grad_fn=<NllLossBackward0>)
# tensor(4.0020, grad_fn=<NllLossBackward0>)
# tensor(3.9612, grad_fn=<NllLossBackward0>)
# tensor(4.3463, grad_fn=<NllLossBackward0>)
# tensor(3.8455, grad_fn=<NllLossBackward0>)
# tensor(3.8388, grad_fn=<NllLossBackward0>)
# tensor(3.8536, grad_fn=<NllLossBackward0>)
# tensor(4.2397, grad_fn=<NllLossBackward0>)
# tensor(4.1724, grad_fn=<NllLossBackward0>)
# tensor(3.8948, grad_fn=<NllLossBackward0>)
# tensor(3.9864, grad_fn=<NllLossBackward0>)
# tensor(4.3543, grad_fn=<NllLossBackward0>)
# tensor(3.9392, grad_fn=<NllLossBackward0>)
# tensor(3.7965, grad_fn=<NllLossBackward0>)
# tensor(3.8691, grad_fn=<NllLossBackward0>)
# tensor(3.7942, grad_fn=<NllLossBackward0>)
# tensor(4.0898, grad_fn=<NllLossBackward0>)
# tensor(3.9134, grad_fn=<NllLossBackward0>)
# tensor(3.7901, grad_fn=<NllLossBackward0>)
# tensor(3.9058, grad_fn=<NllLossBackward0>)
# tensor(3.9075, grad_fn=<NllLossBackward0>)
# tensor(3.9402, grad_fn=<NllLossBackward0>)
# tensor(4.0306, grad_fn=<NllLossBackward0>)
# tensor(4.0048, grad_fn=<NllLossBackward0>)
# tensor(3.8590, grad_fn=<NllLossBackward0>)
# tensor(4.1268, grad_fn=<NllLossBackward0>)
# tensor(3.8713, grad_fn=<NllLossBackward0>)
# tensor(4.1441, grad_fn=<NllLossBackward0>)
# tensor(3.9301, grad_fn=<NllLossBackward0>)
# tensor(4.0349, grad_fn=<NllLossBackward0>)
# tensor(4.0715, grad_fn=<NllLossBackward0>)
# tensor(3.9715, grad_fn=<NllLossBackward0>)
# tensor(4.1240, grad_fn=<NllLossBackward0>)
# tensor(4.2030, grad_fn=<NllLossBackward0>)
# tensor(3.9173, grad_fn=<NllLossBackward0>)
# tensor(4.1706, grad_fn=<NllLossBackward0>)
# tensor(4.0807, grad_fn=<NllLossBackward0>)
# tensor(3.7523, grad_fn=<NllLossBackward0>)
# tensor(4.0937, grad_fn=<NllLossBackward0>)
# tensor(3.8093, grad_fn=<NllLossBackward0>)
# tensor(4.2062, grad_fn=<NllLossBackward0>)
# tensor(4.2049, grad_fn=<NllLossBackward0>)
# tensor(3.9969, grad_fn=<NllLossBackward0>)
# tensor(4.0703, grad_fn=<NllLossBackward0>)
# tensor(3.8704, grad_fn=<NllLossBackward0>)
# tensor(3.6947, grad_fn=<NllLossBackward0>)
# tensor(4.1919, grad_fn=<NllLossBackward0>)
# tensor(3.7523, grad_fn=<NllLossBackward0>)
# tensor(3.7379, grad_fn=<NllLossBackward0>)
# tensor(3.8037, grad_fn=<NllLossBackward0>)
# tensor(3.9614, grad_fn=<NllLossBackward0>)
# tensor(3.6535, grad_fn=<NllLossBackward0>)
# tensor(4.1289, grad_fn=<NllLossBackward0>)
# tensor(3.7393, grad_fn=<NllLossBackward0>)
# tensor(3.9892, grad_fn=<NllLossBackward0>)
# tensor(3.6651, grad_fn=<NllLossBackward0>)
# tensor(3.7056, grad_fn=<NllLossBackward0>)
# tensor(4.1348, grad_fn=<NllLossBackward0>)
# tensor(4.2233, grad_fn=<NllLossBackward0>)
# tensor(4.1805, grad_fn=<NllLossBackward0>)
# tensor(3.9485, grad_fn=<NllLossBackward0>)
# tensor(4.1633, grad_fn=<NllLossBackward0>)
# tensor(3.8190, grad_fn=<NllLossBackward0>)
# tensor(4.1238, grad_fn=<NllLossBackward0>)
# tensor(4.0406, grad_fn=<NllLossBackward0>)
# tensor(3.8886, grad_fn=<NllLossBackward0>)
# tensor(3.9454, grad_fn=<NllLossBackward0>)
# tensor(4.3891, grad_fn=<NllLossBackward0>)
# tensor(3.8155, grad_fn=<NllLossBackward0>)
# tensor(3.8619, grad_fn=<NllLossBackward0>)
# tensor(3.7221, grad_fn=<NllLossBackward0>)
# tensor(4.0173, grad_fn=<NllLossBackward0>)
# tensor(4.5333, grad_fn=<NllLossBackward0>)
# loss: 3.978
# tensor(3.8307, grad_fn=<NllLossBackward0>)
# tensor(3.7702, grad_fn=<NllLossBackward0>)
# tensor(3.7877, grad_fn=<NllLossBackward0>)
# tensor(4.0810, grad_fn=<NllLossBackward0>)
# tensor(3.8415, grad_fn=<NllLossBackward0>)
# tensor(4.1332, grad_fn=<NllLossBackward0>)
# tensor(3.8056, grad_fn=<NllLossBackward0>)
# tensor(3.9733, grad_fn=<NllLossBackward0>)
# tensor(3.6521, grad_fn=<NllLossBackward0>)
# tensor(3.9558, grad_fn=<NllLossBackward0>)
# tensor(4.3946, grad_fn=<NllLossBackward0>)
# tensor(4.0176, grad_fn=<NllLossBackward0>)
# tensor(3.9451, grad_fn=<NllLossBackward0>)
# tensor(3.8004, grad_fn=<NllLossBackward0>)
# tensor(3.8342, grad_fn=<NllLossBackward0>)
# tensor(3.7844, grad_fn=<NllLossBackward0>)
# tensor(4.1114, grad_fn=<NllLossBackward0>)
# tensor(3.8705, grad_fn=<NllLossBackward0>)
# tensor(3.9219, grad_fn=<NllLossBackward0>)
# tensor(4.0113, grad_fn=<NllLossBackward0>)
# tensor(4.2744, grad_fn=<NllLossBackward0>)
# tensor(4.1463, grad_fn=<NllLossBackward0>)
# tensor(3.9927, grad_fn=<NllLossBackward0>)
# tensor(3.8067, grad_fn=<NllLossBackward0>)
# tensor(3.8588, grad_fn=<NllLossBackward0>)
# tensor(4.2445, grad_fn=<NllLossBackward0>)
# tensor(3.9625, grad_fn=<NllLossBackward0>)
# tensor(4.2636, grad_fn=<NllLossBackward0>)
# tensor(3.9011, grad_fn=<NllLossBackward0>)
# tensor(4.6386, grad_fn=<NllLossBackward0>)
# tensor(3.8449, grad_fn=<NllLossBackward0>)
# tensor(4.0910, grad_fn=<NllLossBackward0>)
# tensor(3.6105, grad_fn=<NllLossBackward0>)
# tensor(3.8752, grad_fn=<NllLossBackward0>)
# tensor(4.3088, grad_fn=<NllLossBackward0>)
# tensor(4.1110, grad_fn=<NllLossBackward0>)
# tensor(3.8302, grad_fn=<NllLossBackward0>)
# tensor(3.8553, grad_fn=<NllLossBackward0>)
# tensor(4.2199, grad_fn=<NllLossBackward0>)
# tensor(3.8177, grad_fn=<NllLossBackward0>)
# tensor(4.1184, grad_fn=<NllLossBackward0>)
# tensor(3.9078, grad_fn=<NllLossBackward0>)
# tensor(4.3181, grad_fn=<NllLossBackward0>)
# tensor(3.8799, grad_fn=<NllLossBackward0>)
# tensor(4.2621, grad_fn=<NllLossBackward0>)
# tensor(3.9388, grad_fn=<NllLossBackward0>)
# tensor(3.8334, grad_fn=<NllLossBackward0>)
# tensor(4.3877, grad_fn=<NllLossBackward0>)
# tensor(3.8081, grad_fn=<NllLossBackward0>)
# tensor(4.1393, grad_fn=<NllLossBackward0>)
# tensor(4.0108, grad_fn=<NllLossBackward0>)
# tensor(4.1023, grad_fn=<NllLossBackward0>)
# tensor(4.0761, grad_fn=<NllLossBackward0>)
# tensor(3.6088, grad_fn=<NllLossBackward0>)
# tensor(4.0513, grad_fn=<NllLossBackward0>)
# tensor(3.9990, grad_fn=<NllLossBackward0>)
# tensor(3.7624, grad_fn=<NllLossBackward0>)
# tensor(3.6608, grad_fn=<NllLossBackward0>)
# tensor(4.3124, grad_fn=<NllLossBackward0>)
# tensor(3.9977, grad_fn=<NllLossBackward0>)
# tensor(4.1339, grad_fn=<NllLossBackward0>)
# tensor(3.9157, grad_fn=<NllLossBackward0>)
# tensor(4.0011, grad_fn=<NllLossBackward0>)
# tensor(4.1942, grad_fn=<NllLossBackward0>)
# tensor(4.4192, grad_fn=<NllLossBackward0>)
# tensor(3.7972, grad_fn=<NllLossBackward0>)
# tensor(4.0826, grad_fn=<NllLossBackward0>)
# tensor(3.8408, grad_fn=<NllLossBackward0>)
# tensor(4.1456, grad_fn=<NllLossBackward0>)
# tensor(4.0166, grad_fn=<NllLossBackward0>)
# tensor(3.9430, grad_fn=<NllLossBackward0>)
# tensor(4.0563, grad_fn=<NllLossBackward0>)
# tensor(3.9131, grad_fn=<NllLossBackward0>)
# tensor(4.2216, grad_fn=<NllLossBackward0>)
# tensor(3.9152, grad_fn=<NllLossBackward0>)
# tensor(3.9578, grad_fn=<NllLossBackward0>)
# tensor(3.8730, grad_fn=<NllLossBackward0>)
# tensor(4.0240, grad_fn=<NllLossBackward0>)
# tensor(4.1036, grad_fn=<NllLossBackward0>)
# tensor(4.2335, grad_fn=<NllLossBackward0>)
# tensor(3.9688, grad_fn=<NllLossBackward0>)
# tensor(3.9791, grad_fn=<NllLossBackward0>)
# tensor(3.8847, grad_fn=<NllLossBackward0>)
# tensor(4.1485, grad_fn=<NllLossBackward0>)
# tensor(4.4189, grad_fn=<NllLossBackward0>)
# tensor(4.1208, grad_fn=<NllLossBackward0>)
# tensor(4.3023, grad_fn=<NllLossBackward0>)
# tensor(3.9276, grad_fn=<NllLossBackward0>)
# tensor(3.6728, grad_fn=<NllLossBackward0>)
# tensor(4.0045, grad_fn=<NllLossBackward0>)
# tensor(4.2107, grad_fn=<NllLossBackward0>)
# tensor(4.1113, grad_fn=<NllLossBackward0>)
# tensor(3.8020, grad_fn=<NllLossBackward0>)
# tensor(4.1816, grad_fn=<NllLossBackward0>)
# tensor(3.9830, grad_fn=<NllLossBackward0>)
# tensor(3.9808, grad_fn=<NllLossBackward0>)
# tensor(4.1865, grad_fn=<NllLossBackward0>)
# tensor(4.0037, grad_fn=<NllLossBackward0>)
# tensor(3.8183, grad_fn=<NllLossBackward0>)
# tensor(3.9557, grad_fn=<NllLossBackward0>)
# loss: 4.011
# tensor(4.1791, grad_fn=<NllLossBackward0>)
# tensor(4.1923, grad_fn=<NllLossBackward0>)
# tensor(4.0502, grad_fn=<NllLossBackward0>)
# tensor(3.9325, grad_fn=<NllLossBackward0>)
# tensor(3.9040, grad_fn=<NllLossBackward0>)
# tensor(4.1088, grad_fn=<NllLossBackward0>)
# tensor(3.7721, grad_fn=<NllLossBackward0>)
# tensor(3.8707, grad_fn=<NllLossBackward0>)
# tensor(3.9287, grad_fn=<NllLossBackward0>)
# tensor(4.1351, grad_fn=<NllLossBackward0>)
# tensor(3.9417, grad_fn=<NllLossBackward0>)
# tensor(3.5483, grad_fn=<NllLossBackward0>)
# tensor(4.3134, grad_fn=<NllLossBackward0>)
# tensor(3.8119, grad_fn=<NllLossBackward0>)
# tensor(4.3150, grad_fn=<NllLossBackward0>)
# tensor(3.9930, grad_fn=<NllLossBackward0>)
# tensor(4.1571, grad_fn=<NllLossBackward0>)
# tensor(4.3152, grad_fn=<NllLossBackward0>)
# tensor(3.9528, grad_fn=<NllLossBackward0>)
# tensor(3.8960, grad_fn=<NllLossBackward0>)
# tensor(3.9043, grad_fn=<NllLossBackward0>)
# tensor(3.8258, grad_fn=<NllLossBackward0>)
# tensor(4.2620, grad_fn=<NllLossBackward0>)
# tensor(3.9581, grad_fn=<NllLossBackward0>)
# tensor(4.3957, grad_fn=<NllLossBackward0>)
# tensor(4.0887, grad_fn=<NllLossBackward0>)
# tensor(3.9977, grad_fn=<NllLossBackward0>)
# tensor(4.3673, grad_fn=<NllLossBackward0>)
# tensor(4.0332, grad_fn=<NllLossBackward0>)
# tensor(4.0533, grad_fn=<NllLossBackward0>)
# tensor(3.8040, grad_fn=<NllLossBackward0>)
# tensor(4.2106, grad_fn=<NllLossBackward0>)
# tensor(3.6418, grad_fn=<NllLossBackward0>)
# tensor(3.7771, grad_fn=<NllLossBackward0>)
# tensor(4.3425, grad_fn=<NllLossBackward0>)
# tensor(4.3190, grad_fn=<NllLossBackward0>)
# tensor(3.9586, grad_fn=<NllLossBackward0>)
# tensor(3.7287, grad_fn=<NllLossBackward0>)
# tensor(4.1806, grad_fn=<NllLossBackward0>)
# tensor(4.0182, grad_fn=<NllLossBackward0>)
# tensor(4.3222, grad_fn=<NllLossBackward0>)
# tensor(4.0921, grad_fn=<NllLossBackward0>)
# tensor(3.8914, grad_fn=<NllLossBackward0>)
# tensor(4.0205, grad_fn=<NllLossBackward0>)
# tensor(4.2816, grad_fn=<NllLossBackward0>)
# tensor(3.9063, grad_fn=<NllLossBackward0>)
# tensor(4.0920, grad_fn=<NllLossBackward0>)
# tensor(4.1505, grad_fn=<NllLossBackward0>)
# tensor(3.9441, grad_fn=<NllLossBackward0>)
# tensor(4.3206, grad_fn=<NllLossBackward0>)
# tensor(3.6055, grad_fn=<NllLossBackward0>)
# tensor(3.6104, grad_fn=<NllLossBackward0>)
# tensor(3.9062, grad_fn=<NllLossBackward0>)
# tensor(4.0267, grad_fn=<NllLossBackward0>)
# tensor(4.0957, grad_fn=<NllLossBackward0>)
# tensor(3.7439, grad_fn=<NllLossBackward0>)
# tensor(4.2197, grad_fn=<NllLossBackward0>)
# tensor(4.2003, grad_fn=<NllLossBackward0>)
# tensor(3.9991, grad_fn=<NllLossBackward0>)
# tensor(3.9894, grad_fn=<NllLossBackward0>)
# tensor(4.0867, grad_fn=<NllLossBackward0>)
# tensor(4.4017, grad_fn=<NllLossBackward0>)
# tensor(4.0023, grad_fn=<NllLossBackward0>)
# tensor(3.6764, grad_fn=<NllLossBackward0>)
# tensor(3.8032, grad_fn=<NllLossBackward0>)
# tensor(3.9313, grad_fn=<NllLossBackward0>)
# tensor(4.2089, grad_fn=<NllLossBackward0>)
# tensor(4.1656, grad_fn=<NllLossBackward0>)
# tensor(3.9129, grad_fn=<NllLossBackward0>)
# tensor(4.0131, grad_fn=<NllLossBackward0>)
# tensor(3.7145, grad_fn=<NllLossBackward0>)
# tensor(4.1598, grad_fn=<NllLossBackward0>)
# tensor(3.9834, grad_fn=<NllLossBackward0>)
# tensor(4.1203, grad_fn=<NllLossBackward0>)
# tensor(3.7421, grad_fn=<NllLossBackward0>)
# tensor(3.8494, grad_fn=<NllLossBackward0>)
# tensor(3.8117, grad_fn=<NllLossBackward0>)
# tensor(4.1525, grad_fn=<NllLossBackward0>)
# tensor(4.2266, grad_fn=<NllLossBackward0>)
# tensor(3.9330, grad_fn=<NllLossBackward0>)
# tensor(4.1847, grad_fn=<NllLossBackward0>)
# tensor(3.9355, grad_fn=<NllLossBackward0>)
# tensor(4.3421, grad_fn=<NllLossBackward0>)
# tensor(3.8746, grad_fn=<NllLossBackward0>)
# tensor(3.9695, grad_fn=<NllLossBackward0>)
# tensor(4.0850, grad_fn=<NllLossBackward0>)
# tensor(4.0529, grad_fn=<NllLossBackward0>)
# tensor(4.0396, grad_fn=<NllLossBackward0>)
# tensor(3.7498, grad_fn=<NllLossBackward0>)
# tensor(4.2448, grad_fn=<NllLossBackward0>)
# tensor(4.1313, grad_fn=<NllLossBackward0>)
# tensor(3.8187, grad_fn=<NllLossBackward0>)
# tensor(3.9164, grad_fn=<NllLossBackward0>)
# tensor(3.8564, grad_fn=<NllLossBackward0>)
# tensor(4.0554, grad_fn=<NllLossBackward0>)
# tensor(4.2062, grad_fn=<NllLossBackward0>)
# tensor(3.7178, grad_fn=<NllLossBackward0>)
# tensor(3.8225, grad_fn=<NllLossBackward0>)
# tensor(4.1578, grad_fn=<NllLossBackward0>)
# tensor(4.2673, grad_fn=<NllLossBackward0>)
# loss: 4.015
# tensor(3.7629, grad_fn=<NllLossBackward0>)
# tensor(4.3352, grad_fn=<NllLossBackward0>)
# tensor(3.6112, grad_fn=<NllLossBackward0>)
# tensor(4.3027, grad_fn=<NllLossBackward0>)
# tensor(3.8169, grad_fn=<NllLossBackward0>)
# tensor(3.8620, grad_fn=<NllLossBackward0>)
# tensor(3.9243, grad_fn=<NllLossBackward0>)
# tensor(3.9366, grad_fn=<NllLossBackward0>)
# tensor(4.0265, grad_fn=<NllLossBackward0>)
# tensor(3.9325, grad_fn=<NllLossBackward0>)
# tensor(3.9518, grad_fn=<NllLossBackward0>)
# tensor(4.2711, grad_fn=<NllLossBackward0>)
# tensor(4.4007, grad_fn=<NllLossBackward0>)
# tensor(4.3742, grad_fn=<NllLossBackward0>)
# tensor(4.2397, grad_fn=<NllLossBackward0>)
# tensor(3.9742, grad_fn=<NllLossBackward0>)
# tensor(3.8413, grad_fn=<NllLossBackward0>)
# tensor(3.8342, grad_fn=<NllLossBackward0>)
# tensor(3.5750, grad_fn=<NllLossBackward0>)
# tensor(3.9398, grad_fn=<NllLossBackward0>)
# tensor(4.1222, grad_fn=<NllLossBackward0>)
# tensor(3.8691, grad_fn=<NllLossBackward0>)
# tensor(3.7771, grad_fn=<NllLossBackward0>)
# tensor(3.9285, grad_fn=<NllLossBackward0>)
# tensor(3.8243, grad_fn=<NllLossBackward0>)
# tensor(3.9742, grad_fn=<NllLossBackward0>)
# tensor(3.8882, grad_fn=<NllLossBackward0>)
# tensor(3.8472, grad_fn=<NllLossBackward0>)
# tensor(4.0263, grad_fn=<NllLossBackward0>)
# tensor(4.2299, grad_fn=<NllLossBackward0>)
# tensor(4.0655, grad_fn=<NllLossBackward0>)
# tensor(4.0976, grad_fn=<NllLossBackward0>)
# tensor(3.8860, grad_fn=<NllLossBackward0>)
# tensor(4.2879, grad_fn=<NllLossBackward0>)
# tensor(4.0377, grad_fn=<NllLossBackward0>)
# tensor(3.6811, grad_fn=<NllLossBackward0>)
# tensor(4.3293, grad_fn=<NllLossBackward0>)
# tensor(3.9112, grad_fn=<NllLossBackward0>)
# tensor(3.8638, grad_fn=<NllLossBackward0>)
# tensor(4.0602, grad_fn=<NllLossBackward0>)
# tensor(4.0745, grad_fn=<NllLossBackward0>)
# tensor(4.0108, grad_fn=<NllLossBackward0>)
# tensor(4.2075, grad_fn=<NllLossBackward0>)
# tensor(3.8936, grad_fn=<NllLossBackward0>)
# tensor(4.4258, grad_fn=<NllLossBackward0>)
# tensor(3.9192, grad_fn=<NllLossBackward0>)
# tensor(3.7447, grad_fn=<NllLossBackward0>)
# tensor(3.8716, grad_fn=<NllLossBackward0>)
# tensor(4.1038, grad_fn=<NllLossBackward0>)
# tensor(3.9642, grad_fn=<NllLossBackward0>)
# tensor(4.1001, grad_fn=<NllLossBackward0>)
# tensor(3.7189, grad_fn=<NllLossBackward0>)
# tensor(4.1243, grad_fn=<NllLossBackward0>)
# tensor(4.0386, grad_fn=<NllLossBackward0>)
# tensor(3.9710, grad_fn=<NllLossBackward0>)
# tensor(4.0550, grad_fn=<NllLossBackward0>)
# tensor(4.2102, grad_fn=<NllLossBackward0>)
# tensor(3.9362, grad_fn=<NllLossBackward0>)
# tensor(3.8618, grad_fn=<NllLossBackward0>)
# tensor(3.8455, grad_fn=<NllLossBackward0>)
# tensor(3.9429, grad_fn=<NllLossBackward0>)
# tensor(3.3506, grad_fn=<NllLossBackward0>)
# tensor(4.1951, grad_fn=<NllLossBackward0>)
# tensor(4.1579, grad_fn=<NllLossBackward0>)
# tensor(4.1509, grad_fn=<NllLossBackward0>)
# tensor(3.9143, grad_fn=<NllLossBackward0>)
# tensor(3.6917, grad_fn=<NllLossBackward0>)
# tensor(4.1563, grad_fn=<NllLossBackward0>)
# tensor(3.6319, grad_fn=<NllLossBackward0>)
# Done

# %%
def test(model, loss_fn, test_loader):
    model.eval()
    running_loss = 0
    correct = 0
    total = 0
    for i, data in enumerate(test_loader, 1):
        inputs, labels = data
        inputs = inputs
        labels = labels
        pred = model(inputs)
        loss = loss_fn(pred, labels)

        running_loss += loss.item()
        _, predicted = pred.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()

    avg_loss = running_loss / len(test_loader)
    accuracy = 100. * correct / total

    print('Test Loss: {:.4f}, Accuracy: {}/{} ({:.2f}%)'.format(
        avg_loss, correct, total, accuracy))

# %%
test_loader = torch.utils.data.DataLoader(food101_test_data,
                                          batch_size=64,
                                          shuffle=True)

test(cvt, nn.CrossEntropyLoss(), test_loader)
